# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
import pymongo
# from splinter import Browser
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
import pandas as pd
from config import api_key

# %%
url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"

# %%
members = requests.get(f"{url}&election_year=2011&election_year=2012&election_year=2013&election_year=2014&election_year=2015&election_year=2016&election_year=2017&election_year=2018&election_year=2019&election_year=2020&sort=name&candidate_status=C&page=1&is_active_candidate=true&per_page=20&state=KS&state=MO&office=H&office=S&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false").json()

# %%
members
# Out:
# {'api_version': '1.0',
#  'results': [{'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H0MO06180',
#    'office_full': 'House',
#    'load_date': '2019-07-22T21:11:27+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2019-02-18',
#    'election_districts': ['06'],
#    'first_file_date': '2019-02-18',
#    'cycles': [2020],
#    'candidate_id': 'H0MO06180',
#    'name': 'ABUNDIS, VICTOR',
#    'active_through': 2020,
#    'last_f2_date': '2019-02-18',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 0,
#    'flags': 'S2MO00429',
#    'office_full': 'Senate',
#    'load_date': '2018-02-17T09:16:20+00:00',
#    'election_years': [2012, 2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2012-11-14',
#    'election_districts': ['00', '00'],
#    'first_file_date': '2011-05-18',
#    'cycles': [2012, 2014, 2016, 2018],
#    'candidate_id': 'S2MO00429',
#    'name': 'AKIN, W TODD',
#    'active_through': 2018,
#    'last_f2_date': '2012-11-14',
#    'district': '00',
#    'party': 'REP',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H8MO06118',
#    'office_full': 'House',
#    'load_date': '2018-04-17T21:13:11+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2018-02-07',
#    'election_districts': ['06'],
#    'first_file_date': '2018-02-07',
#    'cycles': [2018],
#    'candidate_id': 'H8MO06118',
#    'name': 'APPLE, GARY WINSTON',
#    'active_through': 2018,
#    'last_f2_date': '2018-02-07',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 5,
#    'flags': 'H0MO05216',
#    'office_full': 'House',
#    'load_date': '2020-08-21T01:04:24+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-06-17',
#    'election_districts': ['05'],
#    'first_file_date': '2020-06-17',
#    'cycles': [2020],
#    'candidate_id': 'H0MO05216',
#    'name': 'BARHAM, JERRY',
#    'active_through': 2020,
#    'last_f2_date': '2020-06-17',
#    'district': '05',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02207',
#    'office_full': 'House',
#    'load_date': '2018-02-07T21:13:27+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-11-26',
#    'election_districts': ['02'],
#    'first_file_date': '2017-11-26',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02207',
#    'name': 'BEVENS, MATTHEW RYAN',
#    'active_through': 2018,
#    'last_f2_date': '2017-11-26',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': True,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 0,
#    'flags': 'S0MO00183',
#    'office_full': 'Senate',
#    'load_date': '2021-04-07T08:02:02+00:00',
#    'election_years': [2010, 2016, 2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2016-12-27',
#    'election_districts': ['00', '00', '00'],
#    'first_file_date': '2009-02-19',
#    'cycles': [2010, 2012, 2014, 2016, 2018, 2020, 2022],
#    'candidate_id': 'S0MO00183',
#    'name': 'BLUNT, ROY',
#    'active_through': 2022,
#    'last_f2_date': '2016-12-27',
#    'district': '00',
#    'party': 'REP',
#    'office': 'S',
#    'inactive_election_years': [2022],
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 0,
#    'flags': 'S0KS00323',
#    'office_full': 'Senate',
#    'load_date': '2021-04-16T01:09:08+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2021-04-15',
#    'election_districts': ['00'],
#    'first_file_date': '2019-10-16',
#    'cycles': [2020, 2022],
#    'candidate_id': 'S0KS00323',
#    'name': 'BOLLIER, BARBARA',
#    'active_through': 2020,
#    'last_f2_date': '2021-04-15',
#    'district': '00',
#    'party': 'DEM',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 0,
#    'flags': 'S0KS00224',
#    'office_full': 'Senate',
#    'load_date': '2019-10-17T21:13:50+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2019-06-28',
#    'election_districts': ['00'],
#    'first_file_date': '2019-06-28',
#    'cycles': [2020],
#    'candidate_id': 'S0KS00224',
#    'name': 'BOYDA, NANCY E',
#    'active_through': 2020,
#    'last_f2_date': '2019-06-28',
#    'district': '00',
#    'party': 'DEM',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 1,
#    'flags': 'H8MO01143',
#    'office_full': 'House',
#    'load_date': '2021-01-29T01:13:04+00:00',
#    'election_years': [2018, 2020, 2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-12-22',
#    'election_districts': ['01', '01', '01'],
#    'first_file_date': '2017-04-20',
#    'cycles': [2018, 2020, 2022],
#    'candidate_id': 'H8MO01143',
#    'name': 'BUSH, CORI',
#    'active_through': 2022,
#    'last_f2_date': '2020-12-22',
#    'district': '01',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 7,
#    'flags': 'H6MO07268',
#    'office_full': 'House',
#    'load_date': '2016-07-11T20:58:46+00:00',
#    'election_years': [2016],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2016-05-16',
#    'election_districts': ['07'],
#    'first_file_date': '2016-05-16',
#    'cycles': [2016],
#    'candidate_id': 'H6MO07268',
#    'name': 'BYRNE, MARY RADASZEWSKI MRS',
#    'active_through': 2016,
#    'last_f2_date': '2016-05-16',
#    'district': '07',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 5,
#    'flags': 'H4MO05234',
#    'office_full': 'House',
#    'load_date': '2021-04-22T01:05:58+00:00',
#    'election_years': [2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2021-04-08',
#    'election_districts': ['05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05'],
#    'first_file_date': '2004-02-06',
#    'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020, 2022],
#    'candidate_id': 'H4MO05234',
#    'name': 'CLEAVER, EMANUEL II',
#    'active_through': 2022,
#    'last_f2_date': '2021-04-08',
#    'district': '05',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 4,
#    'flags': 'H8KS04161',
#    'office_full': 'House',
#    'load_date': '2017-04-10T20:57:55+00:00',
#    'election_years': [2017],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-02-02',
#    'election_districts': ['04'],
#    'first_file_date': '2017-02-02',
#    'cycles': [2018],
#    'candidate_id': 'H8KS04161',
#    'name': 'COBB, ALAN EARL',
#    'active_through': 2017,
#    'last_f2_date': '2017-02-02',
#    'district': '04',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 3,
#    'flags': 'H8KS03155',
#    'office_full': 'House',
#    'load_date': '2021-02-01T01:05:17+00:00',
#    'election_years': [2018, 2020, 2022],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2020-12-21',
#    'election_districts': ['03', '03', '03'],
#    'first_file_date': '2018-02-16',
#    'cycles': [2018, 2020, 2022],
#    'candidate_id': 'H8KS03155',
#    'name': 'DAVIDS, SHARICE',
#    'active_through': 2022,
#    'last_f2_date': '2020-12-21',
#    'district': '03',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 5,
#    'flags': 'H0MO05208',
#    'office_full': 'House',
#    'load_date': '2020-04-16T21:12:37+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-02-03',
#    'election_districts': ['05'],
#    'first_file_date': '2020-02-03',
#    'cycles': [2020],
#    'candidate_id': 'H0MO05208',
#    'name': 'DERKS, RYAN',
#    'active_through': 2020,
#    'last_f2_date': '2020-02-03',
#    'district': '05',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 2,
#    'flags': 'H8MO02190',
#    'office_full': 'House',
#    'load_date': '2017-10-18T21:02:35+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2017-07-17',
#    'election_districts': ['02'],
#    'first_file_date': '2017-07-07',
#    'cycles': [2018],
#    'candidate_id': 'H8MO02190',
#    'name': 'DUNAWAY, KELLIN LYNN',
#    'active_through': 2018,
#    'last_f2_date': '2017-07-07',
#    'district': '02',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 7,
#    'flags': 'H8MO07173',
#    'office_full': 'House',
#    'load_date': '2018-04-17T21:13:11+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2017-07-06',
#    'election_districts': ['07'],
#    'first_file_date': '2017-06-08',
#    'cycles': [2018],
#    'candidate_id': 'H8MO07173',
#    'name': 'EVANS, JIM',
#    'active_through': 2018,
#    'last_f2_date': '2017-07-06',
#    'district': '07',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H0MO06198',
#    'office_full': 'House',
#    'load_date': '2020-04-15T21:14:55+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-02-18',
#    'election_districts': ['06'],
#    'first_file_date': '2020-02-18',
#    'cycles': [2020],
#    'candidate_id': 'H0MO06198',
#    'name': 'FARRIS, RAMONA',
#    'active_through': 2020,
#    'last_f2_date': '2020-02-18',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02132',
#    'office_full': 'House',
#    'load_date': '2018-01-09T21:09:43+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-02-25',
#    'election_districts': ['02'],
#    'first_file_date': '2017-02-25',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02132',
#    'name': 'FIELDS, VERNON JAMES',
#    'active_through': 2018,
#    'last_f2_date': '2017-02-25',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02140',
#    'office_full': 'House',
#    'load_date': '2018-01-09T21:09:43+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-05-17',
#    'election_districts': ['02'],
#    'first_file_date': '2017-04-01',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02140',
#    'name': 'FITZGERALD, STEPHEN EDWARD',
#    'active_through': 2018,
#    'last_f2_date': '2017-05-17',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 3,
#    'flags': 'H8MO03198',
#    'office_full': 'House',
#    'load_date': '2019-08-05T21:05:21+00:00',
#    'election_years': [2018, 2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2019-02-12',
#    'election_districts': ['03', '03'],
#    'first_file_date': '2018-02-14',
#    'cycles': [2018, 2020],
#    'candidate_id': 'H8MO03198',
#    'name': 'GEPPERT, KATY',
#    'active_through': 2020,
#    'last_f2_date': '2019-02-12',
#    'district': '03',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'}],
#  'pagination': {'page': 1, 'count': 50, 'pages': 3, 'per_page': 20}}

# %%
https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false
# Out:
#   File "<ipython-input-9-c541c7b7ccdc>", line 1
#     https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false
#           ^
# SyntaxError: invalid syntax

# %%
newurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key={api_key}&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false"

# %%
newurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false'

# %%
money=requests.get(newurl)

# %%
money.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'pages': 32, 'page': 1, 'per_page': 20, 'count': 627},
#  'results': [{'state': 'KS',
#    'cycle': 2014,
#    'state_full': 'Kansas',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 415.71},
#   {'state': 'KS',
#    'cycle': 2016,
#    'state_full': 'Kansas',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 75.0},
#   {'state': 'AR',
#    'cycle': 2020,
#    'state_full': 'Arkansas',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 2800.0},
#   {'state': 'AZ',
#    'cycle': 2020,
#    'state_full': 'Arizona',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 11200.0},
#   {'state': 'CA',
#    'cycle': 2020,
#    'state_full': 'California',
#    'count': 16,
#    'candidate_id': 'H0KS01123',
#    'total': 13770.2},
#   {'state': 'CO',
#    'cycle': 2020,
#    'state_full': 'Colorado',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 750.0},
#   {'state': 'DC',
#    'cycle': 2020,
#    'state_full': 'District Of Columbia',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 1750.0},
#   {'state': 'FL',
#    'cycle': 2020,
#    'state_full': 'Florida',
#    'count': 2,
#    'candidate_id': 'H0KS01123',
#    'total': 3050.0},
#   {'state': 'GA',
#    'cycle': 2020,
#    'state_full': 'Georgia',
#    'count': 2,
#    'candidate_id': 'H0KS01123',
#    'total': 475.0},
#   {'state': 'IL',
#    'cycle': 2020,
#    'state_full': 'Illinois',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 251.0},
#   {'state': 'KS',
#    'cycle': 2020,
#    'state_full': 'Kansas',
#    'count': 750,
#    'candidate_id': 'H0KS01123',
#    'total': 904158.16},
#   {'state': 'MD',
#    'cycle': 2020,
#    'state_full': 'Maryland',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 2100.0},
#   {'state': 'MI',
#    'cycle': 2020,
#    'state_full': 'Michigan',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 500.0},
#   {'state': 'MN',
#    'cycle': 2020,
#    'state_full': 'Minnesota',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 1000.0},
#   {'state': 'MO',
#    'cycle': 2020,
#    'state_full': 'Missouri',
#    'count': 47,
#    'candidate_id': 'H0KS01123',
#    'total': 49200.0},
#   {'state': 'ND',
#    'cycle': 2020,
#    'state_full': 'North Dakota',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 5600.0},
#   {'state': 'NE',
#    'cycle': 2020,
#    'state_full': 'Nebraska',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 2800.0},
#   {'state': 'OK',
#    'cycle': 2020,
#    'state_full': 'Oklahoma',
#    'count': 3,
#    'candidate_id': 'H0KS01123',
#    'total': 1500.0},
#   {'state': 'OR',
#    'cycle': 2020,
#    'state_full': 'Oregon',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 250.0},
#   {'state': 'TN',
#    'cycle': 2020,
#    'state_full': 'Tennessee',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 250.0}]}

# %%
ksurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per_page=20&sort_hide_null=false&sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&committee_id=C00109017"

# %%
ksurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per_page=20&sort_hide_null=false&sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&committee_id=C00109017'

# %%
ksmoney=requests.get(ksurl)

# %%
ksmoney.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'last_indexes': {'last_index': '4121620051062579651',
#    'sort_null_only': True},
#   'pages': 9565,
#   'per_page': 20,
#   'count': 191298},
#  'results': [{'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '20002 HORIZON BLUFF',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZURHEIDE',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC OPERATIONS INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'THOMAS E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18546839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782583151',
#    'contributor_name': 'ZURHEIDE, THOMAS E',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP-MARKET DEVELOPMENT',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579670',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '190 BRONSON DRIVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZUPKUS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MIDDLEBURY',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'KEVIN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10296839',
#    'contributor_state': 'CT',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '067622319',
#    'contributor_name': 'ZUPKUS, KEVIN A',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP LABOR RELATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579669',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '14 LOCUST DR',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZOLLMANN',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLORISSANT',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'M MICHELLE',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18442839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '630318221',
#    'contributor_name': 'ZOLLMANN, M MICHELLE',
#    'image_number': '25971603261',
#    'contributor_occupation': 'DIRECTOR',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579668',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6N071 MEREDITH RD.',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZANG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MAPLE PARK',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DONNA',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR339683839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601518624',
#    'contributor_name': 'ZANG, DONNA',
#    'image_number': '25971603261',
#    'contributor_occupation': 'HR EMPLOYEE RELATIONS MANAGER II',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579667',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2802CHRISTOPHER BLUFFS',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZALOUDEK',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'OAKVILLE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL YELLOW PAGES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'JOHN M',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18173839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '63129',
#    'contributor_name': 'ZALOUDEK, JOHN M',
#    'image_number': '25971603261',
#    'contributor_occupation': 'MANAGING DIRECTOR ADVERTISING SERVICES',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579666',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6716 CHANNEL RD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZAKRZEWSKI',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WATERFORD',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'AMERITECH SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'COLLEEN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR13498839',
#    'contributor_state': 'WI',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '531852529',
#    'contributor_name': 'ZAKRZEWSKI, COLLEEN A',
#    'image_number': '25971603260',
#    'contributor_occupation': 'MANAGER-QUALITY/M&P/PROCESS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579665',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1248 HEATHER HILL',
#    'contribution_receipt_amount': 35.16,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': 'CRESCENT',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLOSSMOOR',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TROY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 384.36,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR868839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '604221454',
#    'contributor_name': 'YOUNG, TROY L',
#    'image_number': '25971603260',
#    'contributor_occupation': 'LEAD CONTRACTING/SOURCING SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($17.58 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579664',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '11823 ELMSCOURT',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC MANAGEMENT SERVICES L.P.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DAVID ALAN',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR15121839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782302768',
#    'contributor_name': 'YOUNG, DAVID ALAN',
#    'image_number': '25971603260',
#    'contributor_occupation': 'HEAD OF FLIGHT OPERATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579663',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1184 N LNDA VSTA ST',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOSS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ORANGE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'PACIFIC BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MARIA E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR20411839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '928691315',
#    'contributor_name': 'YOSS, MARIA E',
#    'image_number': '25971603259',
#    'contributor_occupation': 'STAFF SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579662',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '5598 KING ROAD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YEAGER',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'LOOMIS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MICHAEL A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR19695839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '956509085',
#    'contributor_name': 'YEAGER, MICHAEL A',
#    'image_number': '25971603259',
#    'contributor_occupation': 'SENIOR DATA ANALYST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579661',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2567 39TH AVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YAM',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'SUNG-LING',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10823839',
# ...
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579654',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1784 CUMBERLAND GREEN',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOOD',
#    'contributor_street_2': 'UNIT #348',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ST CHARLES',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DEBORAH K',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR21687839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601744644',
#    'contributor_name': 'WOOD, DEBORAH K',
#    'image_number': '25971603256',
#    'contributor_occupation': 'BUSINESS MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579653',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '140 LONGFELLOW DR,',
#    'contribution_receipt_amount': 18.8,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WONG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WHEATON',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'EMILY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 205.45,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR3248839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601877410',
#    'contributor_name': 'WONG, EMILY L',
#    'image_number': '25971603256',
#    'contributor_occupation': 'PROJECT MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($9.40 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579652',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '13618 PRISTINE LAKE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOLFF',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'CYPRESS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TIMOTHY J',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18216839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '774296008',
#    'contributor_name': 'WOLFF, TIMOTHY J',
#    'image_number': '25971603256',
#    'contributor_occupation': 'TOP CONSTRUCTION & ENGINEERING OF A RE',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579651',
#    'candidate_office_state': None}]}

# %%
newnewurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per[…]UzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&contributor_zip=66604"

# %%
newnewurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per[…]UzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&contributor_zip=66604'

# %%
newnew=requests.get(ksurl)

# %%
newnew.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'last_indexes': {'last_index': '4121620051062579651',
#    'sort_null_only': True},
#   'pages': 9565,
#   'per_page': 20,
#   'count': 191298},
#  'results': [{'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '20002 HORIZON BLUFF',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZURHEIDE',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC OPERATIONS INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'THOMAS E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18546839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782583151',
#    'contributor_name': 'ZURHEIDE, THOMAS E',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP-MARKET DEVELOPMENT',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579670',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '190 BRONSON DRIVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZUPKUS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MIDDLEBURY',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'KEVIN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10296839',
#    'contributor_state': 'CT',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '067622319',
#    'contributor_name': 'ZUPKUS, KEVIN A',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP LABOR RELATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579669',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '14 LOCUST DR',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZOLLMANN',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLORISSANT',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'M MICHELLE',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18442839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '630318221',
#    'contributor_name': 'ZOLLMANN, M MICHELLE',
#    'image_number': '25971603261',
#    'contributor_occupation': 'DIRECTOR',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579668',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6N071 MEREDITH RD.',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZANG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MAPLE PARK',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DONNA',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR339683839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601518624',
#    'contributor_name': 'ZANG, DONNA',
#    'image_number': '25971603261',
#    'contributor_occupation': 'HR EMPLOYEE RELATIONS MANAGER II',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579667',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2802CHRISTOPHER BLUFFS',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZALOUDEK',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'OAKVILLE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL YELLOW PAGES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'JOHN M',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18173839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '63129',
#    'contributor_name': 'ZALOUDEK, JOHN M',
#    'image_number': '25971603261',
#    'contributor_occupation': 'MANAGING DIRECTOR ADVERTISING SERVICES',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579666',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6716 CHANNEL RD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZAKRZEWSKI',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WATERFORD',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'AMERITECH SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'COLLEEN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR13498839',
#    'contributor_state': 'WI',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '531852529',
#    'contributor_name': 'ZAKRZEWSKI, COLLEEN A',
#    'image_number': '25971603260',
#    'contributor_occupation': 'MANAGER-QUALITY/M&P/PROCESS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579665',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1248 HEATHER HILL',
#    'contribution_receipt_amount': 35.16,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': 'CRESCENT',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLOSSMOOR',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TROY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 384.36,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR868839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '604221454',
#    'contributor_name': 'YOUNG, TROY L',
#    'image_number': '25971603260',
#    'contributor_occupation': 'LEAD CONTRACTING/SOURCING SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($17.58 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579664',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '11823 ELMSCOURT',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC MANAGEMENT SERVICES L.P.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DAVID ALAN',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR15121839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782302768',
#    'contributor_name': 'YOUNG, DAVID ALAN',
#    'image_number': '25971603260',
#    'contributor_occupation': 'HEAD OF FLIGHT OPERATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579663',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1184 N LNDA VSTA ST',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOSS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ORANGE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'PACIFIC BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MARIA E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR20411839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '928691315',
#    'contributor_name': 'YOSS, MARIA E',
#    'image_number': '25971603259',
#    'contributor_occupation': 'STAFF SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579662',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '5598 KING ROAD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YEAGER',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'LOOMIS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MICHAEL A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR19695839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '956509085',
#    'contributor_name': 'YEAGER, MICHAEL A',
#    'image_number': '25971603259',
#    'contributor_occupation': 'SENIOR DATA ANALYST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579661',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2567 39TH AVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YAM',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'SUNG-LING',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10823839',
# ...
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579654',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1784 CUMBERLAND GREEN',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOOD',
#    'contributor_street_2': 'UNIT #348',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ST CHARLES',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DEBORAH K',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR21687839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601744644',
#    'contributor_name': 'WOOD, DEBORAH K',
#    'image_number': '25971603256',
#    'contributor_occupation': 'BUSINESS MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579653',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '140 LONGFELLOW DR,',
#    'contribution_receipt_amount': 18.8,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WONG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WHEATON',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'EMILY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 205.45,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR3248839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601877410',
#    'contributor_name': 'WONG, EMILY L',
#    'image_number': '25971603256',
#    'contributor_occupation': 'PROJECT MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($9.40 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579652',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '13618 PRISTINE LAKE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOLFF',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'CYPRESS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TIMOTHY J',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18216839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '774296008',
#    'contributor_name': 'WOLFF, TIMOTHY J',
#    'image_number': '25971603256',
#    'contributor_occupation': 'TOP CONSTRUCTION & ENGINEERING OF A RE',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579651',
#    'candidate_office_state': None}]}
