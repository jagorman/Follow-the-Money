# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
import pymongo
# from splinter import Browser
from flask import Flask, render_template, redirect
from flask_pymongo import PyMongo
import pandas as pd
from config import api_key

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
db = client.FollowTheMoney
members_collection = db.members
receipt_totals_collection = db.receiptTotals
candidate_data_collection = db.candidate_data
candidate_data_collection.remove()
members_collection.remove()
receipt_totals_collection.remove()
# Out:
# <ipython-input-12-ab10ed2b4962>:7: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   candidate_data_collection.remove()
# <ipython-input-12-ab10ed2b4962>:8: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   members_collection.remove()
# <ipython-input-12-ab10ed2b4962>:9: DeprecationWarning: remove is deprecated. Use delete_one or delete_many instead.
#   receipt_totals_collection.remove()
# {'n': 620, 'ok': 1.0}

# %%
newurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key={api_key}&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false"
money=requests.get(newurl).json()

# %%
total_pages = money['pagination']['pages']
for i in range(1,total_pages+1):
    totals_url=f"https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key={api_key}&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page={i}&sort_nulls_last=false"
    totals_json = requests.get(totals_url).json()
    for item in totals_json['results']:
        receipt_totals_collection.insert_one(item)

# %%
url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"
members = requests.get(f"{url}&election_year=2013&election_year=2014&election_year=2015&election_year=2016&election_year=2017&election_year=2018&election_year=2019&election_year=2020&sort=name&candidate_status=C&page=1&is_active_candidate=true&per_page=20&state=KS&state=MO&office=H&office=S&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false").json()
#find out how many pages of data there are
total_pages = members['pagination']['pages']

# %%
#loop through and get all results
for i in range(1,total_pages+1):
    members = requests.get(f"{url}&election_year=2013&election_year=2014&election_year=2015&election_year=2016&election_year=2017&election_year=2018&election_year=2019&election_year=2020&sort=name&candidate_status=C&page={i}&is_active_candidate=true&per_page=20&state=KS&state=MO&office=H&office=S&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false").json()
    #loop through each record and push to DB
    for item in members["results"]:
        members_collection.insert_one(item)

# %%
# grab the kansas canidates from tbe DB
KS_candidates = members_collection.find({"state":"KS"})
MO_candidates = members_collection.find({"state":"MO"})

# %%
#populat kansas
for cand in KS_candidates:
    candDetail_url = f"https://api.open.fec.gov/v1/candidate/{cand['candidate_id']}/filings/?sort=-receipt_date&sort_nulls_last=false&page=1&sort_hide_null=false&per_page=20&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&sort_null_only=false"
    c_response = requests.get(candDetail_url).json()
    if c_response['results']:
        candidate_data_collection.insert_many(c_response['results'])

# %%
candidates = candidate_data_collection.find()
for candidate in candidates:
    print(candidate)
# Out:
# {'_id': ObjectId('60a9a2405b91a0299f7fc237'), 'bank_depository_street_2': None, 'file_number': 1192456, 'coverage_start_date': None, 'receipt_date': '2017-11-26T00:00:00', 'bank_depository_state': None, 'opposition_personal_funds': None, 'form_type': 'F2', 'sub_id': '4112720171468625137', 'bank_depository_city': None, 'bank_depository_zip': None, 'net_donations': None, 'document_type': None, 'request_type': None, 'total_communication_cost': None, 'most_recent_file_number': 1192456, 'candidate_id': 'H8KS02207', 'form_category': 'STATEMENT', 'total_disbursements': None, 'primary_general_indicator': None, 'pages': 1, 'csv_url': 'https://docquery.fec.gov/csv/456/1192456.csv', 'previous_file_number': 1192456, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1192456.fec', 'update_date': '2017-11-27T00:00:00', 'committee_name': None, 'amendment_version': 0, 'committee_id': 'H8KS02207', 'beginning_image_number': '201711269087655300', 'senate_personal_funds': None, 'report_type_full': None, 'coverage_end_date': None, 'amendment_chain': [1192456.0], 'office': 'H', 'total_individual_contributions': None, 'is_amended': False, 'document_type_full': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS02207/1192456/', 'cash_on_hand_beginning_period': None, 'cycle': 2018, 'treasurer_name': 'BEVENS, MATTHEW RYAN', 'report_type': None, 'state': 'KS', 'pdf_url': 'https://docquery.fec.gov/pdf/300/201711269087655300/201711269087655300.pdf', 'fec_file_id': 'FEC-1192456', 'additional_bank_names': None, 'amendment_indicator': 'N', 'bank_depository_name': None, 'most_recent': True, 'means_filed': 'e-file', 'party': 'REP', 'document_description': 'Statement of candidacy 2017', 'election_year': 2018, 'total_receipts': None, 'ending_image_number': '201711269087655300', 'debts_owed_to_committee': None, 'total_independent_expenditures': None, 'cash_on_hand_end_period': None, 'candidate_name': 'BEVENS, MATTHEW RYAN', 'report_year': 2017, 'debts_owed_by_committee': None, 'committee_type': None, 'house_personal_funds': None, 'bank_depository_street_1': None}
# {'_id': ObjectId('60a9a2415b91a0299f7fc238'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2022, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1511283, 'fec_file_id': 'FEC-1511283', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1449601, 'opposition_personal_funds': None, 'report_year': 2021, 'amendment_indicator': 'A', 'amendment_version': 6, 'report_type_full': None, 'sub_id': '4041620211277752006', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/283/1511283.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/239/202104159443396239/202104159443396239.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': False, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0, 1395118.0, 1405021.0, 1423313.0, 1449601.0, 1511283.0], 'receipt_date': '2021-04-15T00:00:00', 'beginning_image_number': '202104159443396239', 'house_personal_funds': None, 'update_date': '2021-04-16T00:53:33', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202104159443396239', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1511283/', 'most_recent': True, 'total_disbursements': None, 'pages': 1, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2021', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1511283.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc239'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1449601, 'fec_file_id': 'FEC-1449601', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1423313, 'opposition_personal_funds': None, 'report_year': 2020, 'amendment_indicator': 'A', 'amendment_version': 5, 'report_type_full': None, 'sub_id': '4101620201857651151', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/601/1449601.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/495/202010159294170495/202010159294170495.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0, 1395118.0, 1405021.0, 1423313.0, 1449601.0], 'receipt_date': '2020-10-15T00:00:00', 'beginning_image_number': '202010159294170495', 'house_personal_funds': None, 'update_date': '2020-10-16T00:55:49', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202010159294170498', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1449601/', 'most_recent': False, 'total_disbursements': None, 'pages': 4, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2020', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1449601.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23a'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1423313, 'fec_file_id': 'FEC-1423313', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1405021, 'opposition_personal_funds': None, 'report_year': 2020, 'amendment_indicator': 'A', 'amendment_version': 4, 'report_type_full': None, 'sub_id': '4071520201790601161', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/313/1423313.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/194/202007159244966194/202007159244966194.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0, 1395118.0, 1405021.0, 1423313.0], 'receipt_date': '2020-07-15T00:00:00', 'beginning_image_number': '202007159244966194', 'house_personal_funds': None, 'update_date': '2020-07-15T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202007159244966197', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1423313/', 'most_recent': False, 'total_disbursements': None, 'pages': 4, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2020', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1423313.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23b'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1405021, 'fec_file_id': 'FEC-1405021', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1395118, 'opposition_personal_funds': None, 'report_year': 2020, 'amendment_indicator': 'A', 'amendment_version': 3, 'report_type_full': None, 'sub_id': '4051120201742345151', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/021/1405021.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/197/202005119232635197/202005119232635197.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0, 1395118.0, 1405021.0], 'receipt_date': '2020-05-11T00:00:00', 'beginning_image_number': '202005119232635197', 'house_personal_funds': None, 'update_date': '2020-05-11T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202005119232635200', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1405021/', 'most_recent': False, 'total_disbursements': None, 'pages': 4, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2020', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1405021.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23c'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1395118, 'fec_file_id': 'FEC-1395118', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1377610, 'opposition_personal_funds': None, 'report_year': 2020, 'amendment_indicator': 'A', 'amendment_version': 2, 'report_type_full': None, 'sub_id': '4041120201735532150', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/118/1395118.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/197/202004119216641197/202004119216641197.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0, 1395118.0], 'receipt_date': '2020-04-11T00:00:00', 'beginning_image_number': '202004119216641197', 'house_personal_funds': None, 'update_date': '2020-04-11T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202004119216641198', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1395118/', 'most_recent': False, 'total_disbursements': None, 'pages': 2, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2020', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1395118.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23d'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1377610, 'fec_file_id': 'FEC-1377610', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1359075, 'opposition_personal_funds': None, 'report_year': 2020, 'amendment_indicator': 'A', 'amendment_version': 1, 'report_type_full': None, 'sub_id': '4013120201686183162', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/610/1377610.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/387/202001319184668387/202001319184668387.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0, 1377610.0], 'receipt_date': '2020-01-31T00:00:00', 'beginning_image_number': '202001319184668387', 'house_personal_funds': None, 'update_date': '2020-01-31T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '202001319184668387', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1377610/', 'most_recent': False, 'total_disbursements': None, 'pages': 1, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2020', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1377610.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23e'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1359075, 'fec_file_id': 'FEC-1359075', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1359075, 'opposition_personal_funds': None, 'report_year': 2019, 'amendment_indicator': 'N', 'amendment_version': 0, 'report_type_full': None, 'sub_id': '4101620191674360111', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/075/1359075.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/749/201910169164983749/201910169164983749.pdf', 'party': 'DEM', 'most_recent_file_number': 1511283, 'senate_personal_funds': None, 'is_amended': True, 'total_communication_cost': None, 'treasurer_name': 'BOLLIER, BARBARA', 'amendment_chain': [1359075.0], 'receipt_date': '2019-10-16T00:00:00', 'beginning_image_number': '201910169164983749', 'house_personal_funds': None, 'update_date': '2019-10-16T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00323', 'committee_id': 'S0KS00323', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '201910169164983749', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00323/1359075/', 'most_recent': False, 'total_disbursements': None, 'pages': 1, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2019', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1359075.fec', 'candidate_name': 'BOLLIER, BARBARA', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2415b91a0299f7fc23f'), 'bank_depository_street_1': None, 'is_amended': False, 'total_receipts': None, 'most_recent_file_number': 1335955, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1335955.fec', 'document_type': None, 'cash_on_hand_end_period': None, 'csv_url': 'https://docquery.fec.gov/csv/955/1335955.csv', 'treasurer_name': 'BOYDA, NANCY E', 'total_individual_contributions': None, 'update_date': '2019-06-28T00:00:00', 'sub_id': '4062820191659010476', 'fec_file_id': 'FEC-1335955', 'coverage_start_date': None, 'report_year': 2019, 'opposition_personal_funds': None, 'bank_depository_city': None, 'report_type': None, 'house_personal_funds': None, 'cash_on_hand_beginning_period': None, 'pages': 1, 'committee_id': 'S0KS00224', 'coverage_end_date': None, 'candidate_id': 'S0KS00224', 'bank_depository_street_2': None, 'primary_general_indicator': None, 'bank_depository_zip': None, 'document_type_full': None, 'bank_depository_name': None, 'document_description': 'Statement of candidacy 2019', 'request_type': None, 'state': 'KS', 'total_independent_expenditures': None, 'form_type': 'F2', 'file_number': 1335955, 'party': 'DEM', 'additional_bank_names': None, 'total_communication_cost': None, 'office': 'S', 'previous_file_number': 1335955, 'amendment_version': 0, 'committee_name': None, 'cycle': 2020, 'debts_owed_to_committee': None, 'most_recent': True, 'means_filed': 'e-file', 'debts_owed_by_committee': None, 'senate_personal_funds': None, 'committee_type': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00224/1335955/', 'report_type_full': None, 'candidate_name': 'BOYDA, NANCY E', 'amendment_indicator': 'N', 'net_donations': None, 'bank_depository_state': None, 'receipt_date': '2019-06-28T00:00:00', 'pdf_url': 'https://docquery.fec.gov/pdf/374/201906289150361374/201906289150361374.pdf', 'beginning_image_number': '201906289150361374', 'amendment_chain': [1335955.0], 'form_category': 'STATEMENT', 'total_disbursements': None, 'election_year': 2020, 'ending_image_number': '201906289150361374'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc240'), 'pages': 2, 'primary_general_indicator': None, 'ending_image_number': '201702029042410518', 'means_filed': 'e-file', 'previous_file_number': 1147272, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'COBB, ALAN EARL', 'file_number': 1147272, 'cash_on_hand_end_period': None, 'amendment_version': 0, 'net_donations': None, 'document_type_full': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS04161/1147272/', 'committee_name': None, 'fec_file_id': 'FEC-1147272', 'total_individual_contributions': None, 'sub_id': '4020220171369292195', 'senate_personal_funds': None, 'most_recent_file_number': 1147272, 'beginning_image_number': '201702029042410517', 'coverage_end_date': None, 'form_type': 'F2', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': None, 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': True, 'committee_id': 'H8KS04161', 'receipt_date': '2017-02-02T00:00:00', 'treasurer_name': 'COBB, ALAN', 'total_receipts': None, 'election_year': 2017, 'amendment_chain': [1147272.0], 'form_category': 'STATEMENT', 'amendment_indicator': 'N', 'debts_owed_by_committee': None, 'report_year': 2017, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1147272.fec', 'update_date': '2017-02-02T00:00:00', 'committee_type': None, 'document_description': 'Statement of candidacy 2017', 'bank_depository_street_1': None, 'cycle': 2018, 'is_amended': False, 'pdf_url': 'https://docquery.fec.gov/pdf/517/201702029042410517/201702029042410517.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/272/1147272.csv', 'candidate_id': 'H8KS04161', 'total_independent_expenditures': None, 'office': 'H', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2425b91a0299f7fc241'), 'fec_file_id': 'FEC-1483627', 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': 'N', 'is_amended': False, 'net_donations': None, 'document_type': None, 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': 'DAVIDS, SHARICE', 'report_type_full': None, 'most_recent_file_number': 1483627, 'pdf_url': 'https://docquery.fec.gov/pdf/552/202012219393379552/202012219393379552.pdf', 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2020', 'bank_depository_state': None, 'file_number': 1483627, 'most_recent': True, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '4122220201981114157', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2020, 'candidate_id': 'H8KS03155', 'form_type': 'F2', 'cash_on_hand_end_period': None, 'amendment_version': 4, 'cash_on_hand_beginning_period': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03155/1483627/', 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 1, 'receipt_date': '2020-12-21T00:00:00', 'previous_file_number': 1336302, 'ending_image_number': '202012219393379552', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1483627.fec', 'election_year': 2022, 'means_filed': 'e-file', 'report_year': 2020, 'bank_depository_name': None, 'beginning_image_number': '202012219393379552', 'total_individual_contributions': None, 'document_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/627/1483627.csv', 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': [1208992.0, 1330586.0, 1333175.0, 1336302.0, 1483627.0], 'update_date': '2020-12-22T00:56:30', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc242'), 'fec_file_id': 'FEC-1336302', 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': 'A', 'is_amended': True, 'net_donations': None, 'document_type': None, 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': 'DAVIDS, SHARICE', 'report_type_full': None, 'most_recent_file_number': 1483627, 'pdf_url': 'https://docquery.fec.gov/pdf/347/201907019150442347/201907019150442347.pdf', 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2019', 'bank_depository_state': None, 'file_number': 1336302, 'most_recent': False, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '4070220191659057620', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2020, 'candidate_id': 'H8KS03155', 'form_type': 'F2', 'cash_on_hand_end_period': None, 'amendment_version': 3, 'cash_on_hand_beginning_period': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03155/1336302/', 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 3, 'receipt_date': '2019-07-01T00:00:00', 'previous_file_number': 1333175, 'ending_image_number': '201907019150442349', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1336302.fec', 'election_year': 2020, 'means_filed': 'e-file', 'report_year': 2019, 'bank_depository_name': None, 'beginning_image_number': '201907019150442347', 'total_individual_contributions': None, 'document_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/302/1336302.csv', 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': [1208992.0, 1330586.0, 1333175.0, 1336302.0], 'update_date': '2019-07-02T00:00:00', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc243'), 'fec_file_id': 'FEC-1333175', 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': 'N', 'is_amended': True, 'net_donations': None, 'document_type': None, 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': 'BARRETT, LUCY', 'report_type_full': None, 'most_recent_file_number': 1483627, 'pdf_url': 'https://docquery.fec.gov/pdf/284/201906059149933284/201906059149933284.pdf', 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2019', 'bank_depository_state': None, 'file_number': 1333175, 'most_recent': False, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '4060620191657510904', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2020, 'candidate_id': 'H8KS03155', 'form_type': 'F2', 'cash_on_hand_end_period': None, 'amendment_version': 2, 'cash_on_hand_beginning_period': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03155/1333175/', 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 3, 'receipt_date': '2019-06-05T00:00:00', 'previous_file_number': 1330586, 'ending_image_number': '201906059149933286', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1333175.fec', 'election_year': 2020, 'means_filed': 'e-file', 'report_year': 2019, 'bank_depository_name': None, 'beginning_image_number': '201906059149933284', 'total_individual_contributions': None, 'document_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/175/1333175.csv', 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': [1208992.0, 1330586.0, 1333175.0], 'update_date': '2019-06-06T00:00:00', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc244'), 'fec_file_id': 'FEC-1330586', 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': 'A', 'is_amended': True, 'net_donations': None, 'document_type': None, 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': 'DAVIDS, SHARICE', 'report_type_full': None, 'most_recent_file_number': 1483627, 'pdf_url': 'https://docquery.fec.gov/pdf/583/201905149149694583/201905149149694583.pdf', 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2019', 'bank_depository_state': None, 'file_number': 1330586, 'most_recent': False, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '4051420191651859321', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2020, 'candidate_id': 'H8KS03155', 'form_type': 'F2', 'cash_on_hand_end_period': None, 'amendment_version': 1, 'cash_on_hand_beginning_period': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03155/1330586/', 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 3, 'receipt_date': '2019-05-14T00:00:00', 'previous_file_number': 1208992, 'ending_image_number': '201905149149694585', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1330586.fec', 'election_year': 2018, 'means_filed': 'e-file', 'report_year': 2019, 'bank_depository_name': None, 'beginning_image_number': '201905149149694583', 'total_individual_contributions': None, 'document_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/586/1330586.csv', 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': [1208992.0, 1330586.0], 'update_date': '2019-05-15T00:00:00', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc245'), 'fec_file_id': None, 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': None, 'is_amended': False, 'net_donations': None, 'document_type': 'H', 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': None, 'report_type_full': None, 'most_recent_file_number': None, 'pdf_url': 'https://docquery.fec.gov/pdf/925/201904090300036925/201904090300036925.pdf', 'total_communication_cost': None, 'document_description': 'Disavowal Notice 2019', 'bank_depository_state': None, 'file_number': None, 'most_recent': True, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '1040920190037493576', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2020, 'candidate_id': 'H8KS03155', 'form_type': 'F99', 'cash_on_hand_end_period': None, 'amendment_version': 0, 'cash_on_hand_beginning_period': None, 'html_url': None, 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 1, 'receipt_date': '2019-04-09T00:00:00', 'previous_file_number': 0, 'ending_image_number': '201904090300036925', 'fec_url': 'https://docquery.fec.gov/paper/posted/.fec', 'election_year': None, 'means_filed': 'paper', 'report_year': 2019, 'bank_depository_name': None, 'beginning_image_number': '201904090300036925', 'total_individual_contributions': None, 'document_type_full': 'Disavowal Notice', 'csv_url': None, 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': None, 'update_date': '2019-04-09T00:00:00', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'OTHER'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc246'), 'fec_file_id': 'FEC-1208992', 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'amendment_indicator': 'N', 'is_amended': True, 'net_donations': None, 'document_type': None, 'bank_depository_street_1': None, 'debts_owed_by_committee': None, 'treasurer_name': 'DAVIDS, SHARICE', 'report_type_full': None, 'most_recent_file_number': 1483627, 'pdf_url': 'https://docquery.fec.gov/pdf/924/201802169094582924/201802169094582924.pdf', 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2018', 'bank_depository_state': None, 'file_number': 1208992, 'most_recent': False, 'debts_owed_to_committee': None, 'office': 'H', 'sub_id': '4021620181504988463', 'bank_depository_city': None, 'coverage_end_date': None, 'coverage_start_date': None, 'cycle': 2018, 'candidate_id': 'H8KS03155', 'form_type': 'F2', 'cash_on_hand_end_period': None, 'amendment_version': 0, 'cash_on_hand_beginning_period': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03155/1208992/', 'total_receipts': None, 'total_independent_expenditures': None, 'committee_name': None, 'request_type': None, 'primary_general_indicator': None, 'house_personal_funds': None, 'party': 'DEM', 'additional_bank_names': None, 'pages': 1, 'receipt_date': '2018-02-16T00:00:00', 'previous_file_number': 1208992, 'ending_image_number': '201802169094582924', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1208992.fec', 'election_year': 2018, 'means_filed': 'e-file', 'report_year': 2018, 'bank_depository_name': None, 'beginning_image_number': '201802169094582924', 'total_individual_contributions': None, 'document_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/992/1208992.csv', 'report_type': None, 'candidate_name': 'DAVIDS, SHARICE', 'state': 'KS', 'senate_personal_funds': None, 'committee_id': 'H8KS03155', 'total_disbursements': None, 'amendment_chain': [1208992.0], 'update_date': '2018-02-17T00:00:00', 'committee_type': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT'}
# {'_id': ObjectId('60a9a2425b91a0299f7fc247'), 'bank_depository_street_1': None, 'is_amended': False, 'total_receipts': None, 'most_recent_file_number': -9474830, 'document_type': None, 'cash_on_hand_end_period': None, 'csv_url': None, 'treasurer_name': None, 'total_individual_contributions': None, 'update_date': '2017-03-01T00:00:00', 'sub_id': '1030120170033783107', 'fec_file_id': None, 'coverage_start_date': None, 'report_year': 2017, 'opposition_personal_funds': None, 'bank_depository_city': None, 'report_type': None, 'house_personal_funds': None, 'cash_on_hand_beginning_period': None, 'pages': 3, 'committee_id': 'H8KS02132', 'coverage_end_date': None, 'candidate_id': 'H8KS02132', 'bank_depository_street_2': None, 'primary_general_indicator': None, 'bank_depository_zip': None, 'document_type_full': None, 'bank_depository_name': None, 'document_description': 'Statement of candidacy 2017', 'request_type': None, 'state': 'KS', 'total_independent_expenditures': None, 'form_type': 'F2', 'file_number': -9474830, 'party': 'REP', 'additional_bank_names': None, 'total_communication_cost': None, 'office': 'H', 'previous_file_number': -9474830, 'amendment_version': 0, 'committee_name': None, 'cycle': 2018, 'debts_owed_to_committee': None, 'most_recent': True, 'means_filed': 'paper', 'debts_owed_by_committee': None, 'senate_personal_funds': None, 'committee_type': None, 'html_url': None, 'report_type_full': None, 'candidate_name': 'FIELDS, VERNON JAMES', 'amendment_indicator': 'N', 'net_donations': None, 'bank_depository_state': None, 'receipt_date': '2017-02-25T00:00:00', 'pdf_url': 'https://docquery.fec.gov/pdf/965/201703010300142965/201703010300142965.pdf', 'beginning_image_number': '201703010300142965', 'amendment_chain': [-9474830.0], 'form_category': 'STATEMENT', 'total_disbursements': None, 'election_year': 2018, 'ending_image_number': '201703010300142967'}
# {'_id': ObjectId('60a9a2435b91a0299f7fc248'), 'pages': 1, 'primary_general_indicator': None, 'ending_image_number': '201705179053952077', 'means_filed': 'e-file', 'previous_file_number': 1154590, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'FITZGERALD, STEPHEN EDWARD', 'file_number': 1162807, 'cash_on_hand_end_period': None, 'amendment_version': 1, 'net_donations': None, 'document_type_full': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS02140/1162807/', 'committee_name': None, 'fec_file_id': 'FEC-1162807', 'total_individual_contributions': None, 'sub_id': '4051720171404971082', 'senate_personal_funds': None, 'most_recent_file_number': 1162807, 'beginning_image_number': '201705179053952077', 'coverage_end_date': None, 'form_type': 'F2', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': None, 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': True, 'committee_id': 'H8KS02140', 'receipt_date': '2017-05-17T00:00:00', 'treasurer_name': 'FITZGERALD, STEPHEN EDWARD', 'total_receipts': None, 'election_year': 2018, 'amendment_chain': [1154590.0, 1162807.0], 'form_category': 'STATEMENT', 'amendment_indicator': 'A', 'debts_owed_by_committee': None, 'report_year': 2017, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1162807.fec', 'update_date': '2017-05-17T00:00:00', 'committee_type': None, 'document_description': 'Statement of candidacy 2017', 'bank_depository_street_1': None, 'cycle': 2018, 'is_amended': False, 'pdf_url': 'https://docquery.fec.gov/pdf/077/201705179053952077/201705179053952077.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/807/1162807.csv', 'candidate_id': 'H8KS02140', 'total_independent_expenditures': None, 'office': 'H', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2435b91a0299f7fc249'), 'pages': 1, 'primary_general_indicator': None, 'ending_image_number': '201704019051905924', 'means_filed': 'e-file', 'previous_file_number': 1154590, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'FITZGERALD, STEPHEN EDWARD', 'file_number': 1154590, 'cash_on_hand_end_period': None, 'amendment_version': 0, 'net_donations': None, 'document_type_full': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS02140/1154590/', 'committee_name': None, 'fec_file_id': 'FEC-1154590', 'total_individual_contributions': None, 'sub_id': '4040220171392909228', 'senate_personal_funds': None, 'most_recent_file_number': 1162807, 'beginning_image_number': '201704019051905924', 'coverage_end_date': None, 'form_type': 'F2', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': None, 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': False, 'committee_id': 'H8KS02140', 'receipt_date': '2017-04-01T00:00:00', 'treasurer_name': 'FITZGERALD, STEPHEN EDWARD', 'total_receipts': None, 'election_year': 2018, 'amendment_chain': [1154590.0], 'form_category': 'STATEMENT', 'amendment_indicator': 'N', 'debts_owed_by_committee': None, 'report_year': 2017, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1154590.fec', 'update_date': '2017-04-02T00:00:00', 'committee_type': None, 'document_description': 'Statement of candidacy 2017', 'bank_depository_street_1': None, 'cycle': 2018, 'is_amended': True, 'pdf_url': 'https://docquery.fec.gov/pdf/924/201704019051905924/201704019051905924.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': 'https://docquery.fec.gov/csv/590/1154590.csv', 'candidate_id': 'H8KS02140', 'total_independent_expenditures': None, 'office': 'H', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2435b91a0299f7fc24a'), 'sub_id': '4071020191659099662', 'previous_file_number': 1337426, 'report_year': 2019, 'coverage_start_date': None, 'senate_personal_funds': None, 'additional_bank_names': None, 'bank_depository_street_1': None, 'candidate_id': 'H0KS02170', 'election_year': 2020, 'report_type_full': None, 'amendment_chain': [1337426.0], 'csv_url': 'https://docquery.fec.gov/csv/426/1337426.csv', 'fec_file_id': 'FEC-1337426', 'form_type': 'F2', 'primary_general_indicator': None, 'cycle': 2020, 'form_category': 'STATEMENT', 'state': 'KS', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1337426.fec', 'update_date': '2019-07-10T00:00:00', 'committee_type': None, 'party': 'DEM', 'amendment_version': 0, 'committee_name': None, 'pages': 1, 'total_disbursements': None, 'office': 'H', 'cash_on_hand_end_period': None, 'most_recent': True, 'document_type': None, 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2019', 'coverage_end_date': None, 'debts_owed_by_committee': None, 'beginning_image_number': '201907099150527768', 'opposition_personal_funds': None, 'most_recent_file_number': 1337426, 'treasurer_name': 'HODGSON, ABBIE', 'total_receipts': None, 'bank_depository_state': None, 'request_type': None, 'report_type': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H0KS02170/1337426/', 'receipt_date': '2019-07-09T00:00:00', 'house_personal_funds': None, 'file_number': 1337426, 'bank_depository_city': None, 'bank_depository_zip': None, 'cash_on_hand_beginning_period': None, 'bank_depository_name': None, 'committee_id': 'H0KS02170', 'candidate_name': 'HODGSON, ABBIE', 'total_individual_contributions': None, 'means_filed': 'e-file', 'amendment_indicator': 'N', 'ending_image_number': '201907099150527768', 'bank_depository_street_2': None, 'debts_owed_to_committee': None, 'pdf_url': 'https://docquery.fec.gov/pdf/768/201907099150527768/201907099150527768.pdf', 'document_type_full': None, 'total_independent_expenditures': None, 'net_donations': None, 'is_amended': False}
# {'_id': ObjectId('60a9a2445b91a0299f7fc24b'), 'bank_depository_street_2': None, 'previous_file_number': 1236461, 'cycle': 2018, 'document_type': None, 'csv_url': 'https://docquery.fec.gov/csv/932/1237932.csv', 'house_personal_funds': None, 'total_receipts': None, 'amendment_chain': [1236461.0, 1237932.0], 'document_description': 'Statement of candidacy 2018', 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'most_recent': True, 'debts_owed_by_committee': None, 'ending_image_number': '201806149113688149', 'primary_general_indicator': None, 'bank_depository_street_1': None, 'coverage_start_date': None, 'opposition_personal_funds': None, 'committee_name': None, 'update_date': '2018-06-14T00:00:00', 'most_recent_file_number': 1237932, 'total_communication_cost': None, 'report_type_full': None, 'candidate_name': 'KEEGAN, TREVOR', 'election_year': 2018, 'means_filed': 'e-file', 'committee_type': None, 'report_year': 2018, 'amendment_indicator': 'A', 'form_type': 'F2', 'file_number': 1237932, 'total_independent_expenditures': None, 'pages': 1, 'state': 'KS', 'bank_depository_state': None, 'amendment_version': 1, 'bank_depository_city': None, 'total_disbursements': None, 'treasurer_name': 'KEEGAN, TREVOR', 'document_type_full': None, 'bank_depository_zip': None, 'request_type': None, 'candidate_id': 'H8KS03171', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1237932.fec', 'fec_file_id': 'FEC-1237932', 'debts_owed_to_committee': None, 'office': 'H', 'party': 'REP', 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03171/1237932/', 'net_donations': None, 'form_category': 'STATEMENT', 'coverage_end_date': None, 'beginning_image_number': '201806149113688149', 'bank_depository_name': None, 'is_amended': False, 'receipt_date': '2018-06-14T00:00:00', 'total_individual_contributions': None, 'cash_on_hand_end_period': None, 'sub_id': '4061420181570693795', 'senate_personal_funds': None, 'pdf_url': 'https://docquery.fec.gov/pdf/149/201806149113688149/201806149113688149.pdf', 'report_type': None, 'committee_id': 'H8KS03171'}
# {'_id': ObjectId('60a9a2445b91a0299f7fc24c'), 'bank_depository_street_2': None, 'previous_file_number': 0, 'cycle': 2018, 'document_type': None, 'csv_url': None, 'house_personal_funds': None, 'total_receipts': None, 'amendment_chain': None, 'document_description': 'RFAI: Document 2018', 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'most_recent': True, 'debts_owed_by_committee': None, 'ending_image_number': '201806120300011983', 'primary_general_indicator': None, 'bank_depository_street_1': None, 'coverage_start_date': None, 'opposition_personal_funds': None, 'committee_name': None, 'update_date': '2018-06-12T00:00:00', 'most_recent_file_number': None, 'total_communication_cost': None, 'report_type_full': None, 'candidate_name': 'KEEGAN, TREVOR', 'election_year': None, 'means_filed': 'paper', 'committee_type': None, 'report_year': 2018, 'amendment_indicator': None, 'form_type': 'FRQ', 'file_number': None, 'total_independent_expenditures': None, 'pages': 2, 'state': 'KS', 'bank_depository_state': None, 'amendment_version': 0, 'bank_depository_city': None, 'total_disbursements': None, 'treasurer_name': None, 'document_type_full': None, 'bank_depository_zip': None, 'request_type': '5', 'candidate_id': 'H8KS03171', 'fec_url': 'https://docquery.fec.gov/paper/posted/.fec', 'fec_file_id': None, 'debts_owed_to_committee': None, 'office': 'H', 'party': 'REP', 'html_url': None, 'net_donations': None, 'form_category': 'OTHER', 'coverage_end_date': None, 'beginning_image_number': '201806120300011982', 'bank_depository_name': None, 'is_amended': False, 'receipt_date': '2018-06-12T00:00:00', 'total_individual_contributions': None, 'cash_on_hand_end_period': None, 'sub_id': '1061220180036826292', 'senate_personal_funds': None, 'pdf_url': 'https://docquery.fec.gov/pdf/982/201806120300011982/201806120300011982.pdf', 'report_type': None, 'committee_id': 'H8KS03171'}
# {'_id': ObjectId('60a9a2445b91a0299f7fc24d'), 'bank_depository_street_2': None, 'previous_file_number': 1236461, 'cycle': 2018, 'document_type': None, 'csv_url': 'https://docquery.fec.gov/csv/461/1236461.csv', 'house_personal_funds': None, 'total_receipts': None, 'amendment_chain': [1236461.0], 'document_description': 'Statement of candidacy 2018', 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'most_recent': False, 'debts_owed_by_committee': None, 'ending_image_number': '201806059113646674', 'primary_general_indicator': None, 'bank_depository_street_1': None, 'coverage_start_date': None, 'opposition_personal_funds': None, 'committee_name': None, 'update_date': '2018-06-05T00:00:00', 'most_recent_file_number': 1237932, 'total_communication_cost': None, 'report_type_full': None, 'candidate_name': 'KEEGAN, TREVOR', 'election_year': 2018, 'means_filed': 'e-file', 'committee_type': None, 'report_year': 2018, 'amendment_indicator': 'N', 'form_type': 'F2', 'file_number': 1236461, 'total_independent_expenditures': None, 'pages': 1, 'state': 'KS', 'bank_depository_state': None, 'amendment_version': 0, 'bank_depository_city': None, 'total_disbursements': None, 'treasurer_name': 'KEEGAN, TREVOR', 'document_type_full': None, 'bank_depository_zip': None, 'request_type': None, 'candidate_id': 'H8KS03171', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1236461.fec', 'fec_file_id': 'FEC-1236461', 'debts_owed_to_committee': None, 'office': 'H', 'party': 'REP', 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03171/1236461/', 'net_donations': None, 'form_category': 'STATEMENT', 'coverage_end_date': None, 'beginning_image_number': '201806059113646674', 'bank_depository_name': None, 'is_amended': True, 'receipt_date': '2018-06-05T00:00:00', 'total_individual_contributions': None, 'cash_on_hand_end_period': None, 'sub_id': '4060520181570580397', 'senate_personal_funds': None, 'pdf_url': 'https://docquery.fec.gov/pdf/674/201806059113646674/201806059113646674.pdf', 'report_type': None, 'committee_id': 'H8KS03171'}
# ...
# {'_id': ObjectId('60a9a2465b91a0299f7fc264'), 'pages': 3, 'primary_general_indicator': None, 'ending_image_number': '13020270459', 'means_filed': 'paper', 'previous_file_number': -4990845, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'MORAN, JERRY', 'file_number': -4990845, 'cash_on_hand_end_period': None, 'amendment_version': 0, 'net_donations': None, 'document_type_full': None, 'html_url': None, 'committee_name': None, 'fec_file_id': None, 'total_individual_contributions': None, 'sub_id': '1070220130014222415', 'senate_personal_funds': None, 'most_recent_file_number': 1503467, 'beginning_image_number': '13020270457', 'coverage_end_date': None, 'form_type': 'F2', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': None, 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': False, 'committee_id': 'S0KS00091', 'receipt_date': '2013-06-28T00:00:00', 'treasurer_name': None, 'total_receipts': None, 'election_year': 2016, 'amendment_chain': [-4990845.0], 'form_category': 'STATEMENT', 'amendment_indicator': 'N', 'debts_owed_by_committee': None, 'report_year': 2013, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'update_date': '2013-07-02T00:00:00', 'committee_type': None, 'document_description': 'Statement of candidacy 2013', 'bank_depository_street_1': None, 'cycle': 2014, 'is_amended': True, 'pdf_url': 'https://docquery.fec.gov/pdf/457/13020270457/13020270457.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': None, 'candidate_id': 'S0KS00091', 'total_independent_expenditures': None, 'office': 'S', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2465b91a0299f7fc265'), 'pages': 2, 'primary_general_indicator': None, 'ending_image_number': '11330009698', 'means_filed': 'paper', 'previous_file_number': 0, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'MORAN, JERRY', 'file_number': None, 'cash_on_hand_end_period': None, 'amendment_version': 0, 'net_donations': None, 'document_type_full': 'Disavowal Notice', 'html_url': None, 'committee_name': None, 'fec_file_id': None, 'total_individual_contributions': None, 'sub_id': '1052220110005806750', 'senate_personal_funds': None, 'most_recent_file_number': None, 'beginning_image_number': '11330009697', 'coverage_end_date': None, 'form_type': 'F99', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': 'H', 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': True, 'committee_id': 'S0KS00091', 'receipt_date': '2011-05-20T00:00:00', 'treasurer_name': None, 'total_receipts': None, 'election_year': None, 'amendment_chain': None, 'form_category': 'OTHER', 'amendment_indicator': None, 'debts_owed_by_committee': None, 'report_year': 2011, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'fec_url': 'https://docquery.fec.gov/paper/posted/.fec', 'update_date': '2011-05-22T00:00:00', 'committee_type': None, 'document_description': 'Disavowal Notice 2011', 'bank_depository_street_1': None, 'cycle': 2012, 'is_amended': False, 'pdf_url': 'https://docquery.fec.gov/pdf/697/11330009697/11330009697.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': None, 'candidate_id': 'S0KS00091', 'total_independent_expenditures': None, 'office': 'S', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2465b91a0299f7fc266'), 'pages': 3, 'primary_general_indicator': None, 'ending_image_number': '28020712205', 'means_filed': 'paper', 'previous_file_number': None, 'coverage_start_date': None, 'request_type': None, 'bank_depository_state': None, 'bank_depository_zip': None, 'candidate_name': 'MORAN, JERRY', 'file_number': None, 'cash_on_hand_end_period': None, 'amendment_version': None, 'net_donations': None, 'document_type_full': None, 'html_url': None, 'committee_name': None, 'fec_file_id': None, 'total_individual_contributions': None, 'sub_id': '1111020080000639496', 'senate_personal_funds': None, 'most_recent_file_number': None, 'beginning_image_number': '28020712203', 'coverage_end_date': None, 'form_type': 'F2', 'house_personal_funds': None, 'bank_depository_city': None, 'document_type': None, 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'report_type': None, 'most_recent': None, 'committee_id': 'S0KS00091', 'receipt_date': '2008-11-07T00:00:00', 'treasurer_name': None, 'total_receipts': None, 'election_year': 2010, 'amendment_chain': None, 'form_category': 'STATEMENT', 'amendment_indicator': 'N', 'debts_owed_by_committee': None, 'report_year': 2008, 'party': 'REP', 'opposition_personal_funds': None, 'total_communication_cost': None, 'fec_url': 'https://docquery.fec.gov/paper/posted/.fec', 'update_date': '2008-11-10T00:00:00', 'committee_type': None, 'document_description': 'Statement of candidacy 2008', 'bank_depository_street_1': None, 'cycle': 2008, 'is_amended': None, 'pdf_url': 'https://docquery.fec.gov/pdf/203/28020712203/28020712203.pdf', 'debts_owed_to_committee': None, 'total_disbursements': None, 'state': 'KS', 'report_type_full': None, 'csv_url': None, 'candidate_id': 'S0KS00091', 'total_independent_expenditures': None, 'office': 'S', 'bank_depository_street_2': None, 'bank_depository_name': None}
# {'_id': ObjectId('60a9a2465b91a0299f7fc267'), 'sub_id': '4051620181565783790', 'previous_file_number': 1231523, 'report_year': 2018, 'coverage_start_date': None, 'senate_personal_funds': None, 'additional_bank_names': None, 'bank_depository_street_1': None, 'candidate_id': 'H8KS02249', 'election_year': 2018, 'report_type_full': None, 'amendment_chain': [1231523.0], 'csv_url': 'https://docquery.fec.gov/csv/523/1231523.csv', 'fec_file_id': 'FEC-1231523', 'form_type': 'F2', 'primary_general_indicator': None, 'cycle': 2018, 'form_category': 'STATEMENT', 'state': 'KS', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1231523.fec', 'update_date': '2018-05-16T00:00:00', 'committee_type': None, 'party': 'REP', 'amendment_version': 0, 'committee_name': None, 'pages': 1, 'total_disbursements': None, 'office': 'H', 'cash_on_hand_end_period': None, 'most_recent': True, 'document_type': None, 'total_communication_cost': None, 'document_description': 'Statement of candidacy 2018', 'coverage_end_date': None, 'debts_owed_by_committee': None, 'beginning_image_number': '201805169112045172', 'opposition_personal_funds': None, 'most_recent_file_number': 1231523, 'treasurer_name': 'PYLE, DENNIS', 'total_receipts': None, 'bank_depository_state': None, 'request_type': None, 'report_type': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS02249/1231523/', 'receipt_date': '2018-05-16T00:00:00', 'house_personal_funds': None, 'file_number': 1231523, 'bank_depository_city': None, 'bank_depository_zip': None, 'cash_on_hand_beginning_period': None, 'bank_depository_name': None, 'committee_id': 'H8KS02249', 'candidate_name': 'PYLE, DENNIS', 'total_individual_contributions': None, 'means_filed': 'e-file', 'amendment_indicator': 'N', 'ending_image_number': '201805169112045172', 'bank_depository_street_2': None, 'debts_owed_to_committee': None, 'pdf_url': 'https://docquery.fec.gov/pdf/172/201805169112045172/201805169112045172.pdf', 'document_type_full': None, 'total_independent_expenditures': None, 'net_donations': None, 'is_amended': False}
# {'_id': ObjectId('60a9a2475b91a0299f7fc268'), 'bank_depository_street_2': None, 'previous_file_number': 1197275, 'cycle': 2018, 'document_type': None, 'csv_url': 'https://docquery.fec.gov/csv/275/1197275.csv', 'house_personal_funds': None, 'total_receipts': None, 'amendment_chain': [1197275.0], 'document_description': 'Statement of candidacy 2018', 'additional_bank_names': None, 'cash_on_hand_beginning_period': None, 'most_recent': True, 'debts_owed_by_committee': None, 'ending_image_number': '201801139090406595', 'primary_general_indicator': None, 'bank_depository_street_1': None, 'coverage_start_date': None, 'opposition_personal_funds': None, 'committee_name': None, 'update_date': '2018-01-13T00:00:00', 'most_recent_file_number': 1197275, 'total_communication_cost': None, 'report_type_full': None, 'candidate_name': 'TANNAHILL, TYLER NATHAN', 'election_year': 2018, 'means_filed': 'e-file', 'committee_type': None, 'report_year': 2018, 'amendment_indicator': 'N', 'form_type': 'F2', 'file_number': 1197275, 'total_independent_expenditures': None, 'pages': 1, 'state': 'KS', 'bank_depository_state': None, 'amendment_version': 0, 'bank_depository_city': None, 'total_disbursements': None, 'treasurer_name': 'TANNAHILL, TYLER NATHAN', 'document_type_full': None, 'bank_depository_zip': None, 'request_type': None, 'candidate_id': 'H8KS02215', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1197275.fec', 'fec_file_id': 'FEC-1197275', 'debts_owed_to_committee': None, 'office': 'H', 'party': 'REP', 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS02215/1197275/', 'net_donations': None, 'form_category': 'STATEMENT', 'coverage_end_date': None, 'beginning_image_number': '201801139090406595', 'bank_depository_name': None, 'is_amended': False, 'receipt_date': '2018-01-13T00:00:00', 'total_individual_contributions': None, 'cash_on_hand_end_period': None, 'sub_id': '4011320181502841144', 'senate_personal_funds': None, 'pdf_url': 'https://docquery.fec.gov/pdf/595/201801139090406595/201801139090406595.pdf', 'report_type': None, 'committee_id': 'H8KS02215'}
# {'_id': ObjectId('60a9a2475b91a0299f7fc269'), 'most_recent': True, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H0KS02212/1410573/', 'report_year': 2020, 'ending_image_number': '202006099239656862', 'senate_personal_funds': None, 'previous_file_number': 1410573, 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1410573.fec', 'primary_general_indicator': None, 'bank_depository_zip': None, 'form_category': 'STATEMENT', 'pages': 1, 'opposition_personal_funds': None, 'bank_depository_street_2': None, 'document_type_full': None, 'sub_id': '4060920201774525154', 'document_type': None, 'bank_depository_state': None, 'candidate_id': 'H0KS02212', 'candidate_name': 'TAYLOR, DENNIS R MR.', 'document_description': 'Statement of candidacy 2020', 'amendment_chain': [1410573.0], 'bank_depository_city': None, 'total_communication_cost': None, 'report_type_full': None, 'cash_on_hand_beginning_period': None, 'amendment_version': 0, 'total_receipts': None, 'total_individual_contributions': None, 'csv_url': 'https://docquery.fec.gov/csv/573/1410573.csv', 'election_year': 2020, 'committee_id': 'H0KS02212', 'committee_type': None, 'is_amended': False, 'debts_owed_by_committee': None, 'additional_bank_names': None, 'party': 'REP', 'debts_owed_to_committee': None, 'cycle': 2020, 'treasurer_name': 'TAYLOR, DENNIS R MR.', 'means_filed': 'e-file', 'state': 'KS', 'coverage_end_date': None, 'total_independent_expenditures': None, 'house_personal_funds': None, 'update_date': '2020-06-09T00:00:00', 'bank_depository_street_1': None, 'total_disbursements': None, 'committee_name': None, 'amendment_indicator': 'N', 'cash_on_hand_end_period': None, 'most_recent_file_number': 1410573, 'office': 'H', 'beginning_image_number': '202006099239656862', 'pdf_url': 'https://docquery.fec.gov/pdf/862/202006099239656862/202006099239656862.pdf', 'bank_depository_name': None, 'request_type': None, 'coverage_start_date': None, 'fec_file_id': 'FEC-1410573', 'file_number': 1410573, 'report_type': None, 'form_type': 'F2', 'receipt_date': '2020-06-09T00:00:00', 'net_donations': None}
# {'_id': ObjectId('60a9a2485b91a0299f7fc26a'), 'bank_depository_city': None, 'committee_name': None, 'means_filed': 'e-file', 'cycle': 2020, 'bank_depository_state': None, 'total_receipts': None, 'form_category': 'STATEMENT', 'total_individual_contributions': None, 'document_type': None, 'cash_on_hand_beginning_period': None, 'file_number': 1347105, 'fec_file_id': 'FEC-1347105', 'document_type_full': None, 'report_type': None, 'previous_file_number': 1347105, 'opposition_personal_funds': None, 'report_year': 2019, 'amendment_indicator': 'N', 'amendment_version': 0, 'report_type_full': None, 'sub_id': '4080720191662999454', 'cash_on_hand_end_period': None, 'additional_bank_names': None, 'csv_url': 'https://docquery.fec.gov/csv/105/1347105.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/137/201908079161364137/201908079161364137.pdf', 'party': 'REP', 'most_recent_file_number': 1347105, 'senate_personal_funds': None, 'is_amended': False, 'total_communication_cost': None, 'treasurer_name': 'WAGLE, SUSAN', 'amendment_chain': [1347105.0], 'receipt_date': '2019-08-07T00:00:00', 'beginning_image_number': '201908079161364137', 'house_personal_funds': None, 'update_date': '2019-08-07T00:00:00', 'net_donations': None, 'state': 'KS', 'coverage_end_date': None, 'candidate_id': 'S0KS00299', 'committee_id': 'S0KS00299', 'bank_depository_zip': None, 'office': 'S', 'ending_image_number': '201908079161364137', 'bank_depository_street_1': None, 'bank_depository_name': None, 'bank_depository_street_2': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/S0KS00299/1347105/', 'most_recent': True, 'total_disbursements': None, 'pages': 1, 'total_independent_expenditures': None, 'document_description': 'Statement of candidacy 2019', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1347105.fec', 'candidate_name': 'WAGLE, SUSAN', 'committee_type': None, 'coverage_start_date': None, 'debts_owed_by_committee': None, 'election_year': 2020, 'debts_owed_to_committee': None, 'primary_general_indicator': None, 'request_type': None, 'form_type': 'F2'}
# {'_id': ObjectId('60a9a2485b91a0299f7fc26b'), 'party': 'DEM', 'fec_url': 'https://docquery.fec.gov/dcdev/posted/1210721.fec', 'bank_depository_zip': None, 'report_type_full': None, 'coverage_start_date': None, 'file_number': 1210721, 'bank_depository_state': None, 'committee_id': 'H8KS03163', 'ending_image_number': '201802219095501681', 'total_disbursements': None, 'document_type': None, 'cycle': 2018, 'committee_name': None, 'candidate_id': 'H8KS03163', 'debts_owed_to_committee': None, 'bank_depository_city': None, 'state': 'KS', 'office': 'H', 'report_type': None, 'previous_file_number': 1210721, 'request_type': None, 'most_recent': True, 'total_receipts': None, 'total_communication_cost': None, 'additional_bank_names': None, 'report_year': 2018, 'sub_id': '4022120181514328864', 'most_recent_file_number': 1210721, 'form_category': 'STATEMENT', 'election_year': 2018, 'debts_owed_by_committee': None, 'total_independent_expenditures': None, 'csv_url': 'https://docquery.fec.gov/csv/721/1210721.csv', 'pdf_url': 'https://docquery.fec.gov/pdf/681/201802219095501681/201802219095501681.pdf', 'senate_personal_funds': None, 'bank_depository_street_2': None, 'beginning_image_number': '201802219095501681', 'is_amended': False, 'treasurer_name': 'WILLIAMS, SYLVIA', 'house_personal_funds': None, 'cash_on_hand_end_period': None, 'opposition_personal_funds': None, 'html_url': 'https://docquery.fec.gov/cgi-bin/forms/H8KS03163/1210721/', 'amendment_chain': [1210721.0], 'total_individual_contributions': None, 'bank_depository_street_1': None, 'net_donations': None, 'committee_type': None, 'update_date': '2018-02-21T00:00:00', 'primary_general_indicator': None, 'coverage_end_date': None, 'candidate_name': 'WILLIAMS, SYLVIA', 'receipt_date': '2018-02-21T00:00:00', 'pages': 1, 'bank_depository_name': None, 'cash_on_hand_beginning_period': None, 'amendment_indicator': 'N', 'amendment_version': 0, 'form_type': 'F2', 'fec_file_id': 'FEC-1210721', 'document_type_full': None, 'document_description': 'Statement of candidacy 2018', 'means_filed': 'e-file'}

# %%
#populat missouri
for cand in MO_candidates:
    candDetail_url = f"https://api.open.fec.gov/v2/candidate/{cand['candidate_id']}/filings/?sort=-receipt_date&sort_nulls_last=false&page=1&sort_hide_null=false&per_page=20&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&sort_null_only=false"
    c_response = requests.get(candDetail_url).json()
    if c_response['results']:
        candidate_data_collection.insert_many(c_response['results'])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-673932674730> in <module>
#       2 for cand in MO_candidates:
#       3     candDetail_url = f"https://api.open.fec.gov/v2/candidate/{cand['candidate_id']}/filings/?sort=-receipt_date&sort_nulls_last=false&page=1&sort_hide_null=false&per_page=20&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&sort_null_only=false"
# ----> 4     c_response = requests.get(candDetail_url).json()
#       5     if c_response['results']:
#       6         candidate_data_collection.insert_many(c_response['results'])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     896                     # used.
#     897                     pass
# --> 898         return complexjson.loads(self.text, **kwargs)
#     899
#     900     @property
#
# ~/opt/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/opt/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
candidates = candidate_data_collection.find()
for candidate in candidates:
    print(candidate)

# %%
url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"

# %%
members = requests.get(f"{url}&election_year=2011&election_year=2012&election_year=2013&election_year=2014&election_year=2015&election_year=2016&election_year=2017&election_year=2018&election_year=2019&election_year=2020&sort=name&candidate_status=C&page=1&is_active_candidate=true&per_page=20&state=KS&state=MO&office=H&office=S&sort_hide_null=false&sort_null_only=false&sort_nulls_last=false").json()

# %%
members
# Out:
# {'api_version': '1.0',
#  'results': [{'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H0MO06180',
#    'office_full': 'House',
#    'load_date': '2019-07-22T21:11:27+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2019-02-18',
#    'election_districts': ['06'],
#    'first_file_date': '2019-02-18',
#    'cycles': [2020],
#    'candidate_id': 'H0MO06180',
#    'name': 'ABUNDIS, VICTOR',
#    'active_through': 2020,
#    'last_f2_date': '2019-02-18',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 0,
#    'flags': 'S2MO00429',
#    'office_full': 'Senate',
#    'load_date': '2018-02-17T09:16:20+00:00',
#    'election_years': [2012, 2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2012-11-14',
#    'election_districts': ['00', '00'],
#    'first_file_date': '2011-05-18',
#    'cycles': [2012, 2014, 2016, 2018],
#    'candidate_id': 'S2MO00429',
#    'name': 'AKIN, W TODD',
#    'active_through': 2018,
#    'last_f2_date': '2012-11-14',
#    'district': '00',
#    'party': 'REP',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H8MO06118',
#    'office_full': 'House',
#    'load_date': '2018-04-17T21:13:11+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2018-02-07',
#    'election_districts': ['06'],
#    'first_file_date': '2018-02-07',
#    'cycles': [2018],
#    'candidate_id': 'H8MO06118',
#    'name': 'APPLE, GARY WINSTON',
#    'active_through': 2018,
#    'last_f2_date': '2018-02-07',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 5,
#    'flags': 'H0MO05216',
#    'office_full': 'House',
#    'load_date': '2020-08-21T01:04:24+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-06-17',
#    'election_districts': ['05'],
#    'first_file_date': '2020-06-17',
#    'cycles': [2020],
#    'candidate_id': 'H0MO05216',
#    'name': 'BARHAM, JERRY',
#    'active_through': 2020,
#    'last_f2_date': '2020-06-17',
#    'district': '05',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02207',
#    'office_full': 'House',
#    'load_date': '2018-02-07T21:13:27+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-11-26',
#    'election_districts': ['02'],
#    'first_file_date': '2017-11-26',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02207',
#    'name': 'BEVENS, MATTHEW RYAN',
#    'active_through': 2018,
#    'last_f2_date': '2017-11-26',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': True,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 0,
#    'flags': 'S0MO00183',
#    'office_full': 'Senate',
#    'load_date': '2021-04-07T08:02:02+00:00',
#    'election_years': [2010, 2016, 2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2016-12-27',
#    'election_districts': ['00', '00', '00'],
#    'first_file_date': '2009-02-19',
#    'cycles': [2010, 2012, 2014, 2016, 2018, 2020, 2022],
#    'candidate_id': 'S0MO00183',
#    'name': 'BLUNT, ROY',
#    'active_through': 2022,
#    'last_f2_date': '2016-12-27',
#    'district': '00',
#    'party': 'REP',
#    'office': 'S',
#    'inactive_election_years': [2022],
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 0,
#    'flags': 'S0KS00323',
#    'office_full': 'Senate',
#    'load_date': '2021-04-16T01:09:08+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2021-04-15',
#    'election_districts': ['00'],
#    'first_file_date': '2019-10-16',
#    'cycles': [2020, 2022],
#    'candidate_id': 'S0KS00323',
#    'name': 'BOLLIER, BARBARA',
#    'active_through': 2020,
#    'last_f2_date': '2021-04-15',
#    'district': '00',
#    'party': 'DEM',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 0,
#    'flags': 'S0KS00224',
#    'office_full': 'Senate',
#    'load_date': '2019-10-17T21:13:50+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2019-06-28',
#    'election_districts': ['00'],
#    'first_file_date': '2019-06-28',
#    'cycles': [2020],
#    'candidate_id': 'S0KS00224',
#    'name': 'BOYDA, NANCY E',
#    'active_through': 2020,
#    'last_f2_date': '2019-06-28',
#    'district': '00',
#    'party': 'DEM',
#    'office': 'S',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 1,
#    'flags': 'H8MO01143',
#    'office_full': 'House',
#    'load_date': '2021-01-29T01:13:04+00:00',
#    'election_years': [2018, 2020, 2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-12-22',
#    'election_districts': ['01', '01', '01'],
#    'first_file_date': '2017-04-20',
#    'cycles': [2018, 2020, 2022],
#    'candidate_id': 'H8MO01143',
#    'name': 'BUSH, CORI',
#    'active_through': 2022,
#    'last_f2_date': '2020-12-22',
#    'district': '01',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 7,
#    'flags': 'H6MO07268',
#    'office_full': 'House',
#    'load_date': '2016-07-11T20:58:46+00:00',
#    'election_years': [2016],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2016-05-16',
#    'election_districts': ['07'],
#    'first_file_date': '2016-05-16',
#    'cycles': [2016],
#    'candidate_id': 'H6MO07268',
#    'name': 'BYRNE, MARY RADASZEWSKI MRS',
#    'active_through': 2016,
#    'last_f2_date': '2016-05-16',
#    'district': '07',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 5,
#    'flags': 'H4MO05234',
#    'office_full': 'House',
#    'load_date': '2021-04-22T01:05:58+00:00',
#    'election_years': [2004,
#     2006,
#     2008,
#     2010,
#     2012,
#     2014,
#     2016,
#     2018,
#     2020,
#     2022],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2021-04-08',
#    'election_districts': ['05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05',
#     '05'],
#    'first_file_date': '2004-02-06',
#    'cycles': [2004, 2006, 2008, 2010, 2012, 2014, 2016, 2018, 2020, 2022],
#    'candidate_id': 'H4MO05234',
#    'name': 'CLEAVER, EMANUEL II',
#    'active_through': 2022,
#    'last_f2_date': '2021-04-08',
#    'district': '05',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 4,
#    'flags': 'H8KS04161',
#    'office_full': 'House',
#    'load_date': '2017-04-10T20:57:55+00:00',
#    'election_years': [2017],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-02-02',
#    'election_districts': ['04'],
#    'first_file_date': '2017-02-02',
#    'cycles': [2018],
#    'candidate_id': 'H8KS04161',
#    'name': 'COBB, ALAN EARL',
#    'active_through': 2017,
#    'last_f2_date': '2017-02-02',
#    'district': '04',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'I',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Incumbent',
#    'district_number': 3,
#    'flags': 'H8KS03155',
#    'office_full': 'House',
#    'load_date': '2021-02-01T01:05:17+00:00',
#    'election_years': [2018, 2020, 2022],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2020-12-21',
#    'election_districts': ['03', '03', '03'],
#    'first_file_date': '2018-02-16',
#    'cycles': [2018, 2020, 2022],
#    'candidate_id': 'H8KS03155',
#    'name': 'DAVIDS, SHARICE',
#    'active_through': 2022,
#    'last_f2_date': '2020-12-21',
#    'district': '03',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 5,
#    'flags': 'H0MO05208',
#    'office_full': 'House',
#    'load_date': '2020-04-16T21:12:37+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-02-03',
#    'election_districts': ['05'],
#    'first_file_date': '2020-02-03',
#    'cycles': [2020],
#    'candidate_id': 'H0MO05208',
#    'name': 'DERKS, RYAN',
#    'active_through': 2020,
#    'last_f2_date': '2020-02-03',
#    'district': '05',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 2,
#    'flags': 'H8MO02190',
#    'office_full': 'House',
#    'load_date': '2017-10-18T21:02:35+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2017-07-17',
#    'election_districts': ['02'],
#    'first_file_date': '2017-07-07',
#    'cycles': [2018],
#    'candidate_id': 'H8MO02190',
#    'name': 'DUNAWAY, KELLIN LYNN',
#    'active_through': 2018,
#    'last_f2_date': '2017-07-07',
#    'district': '02',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 7,
#    'flags': 'H8MO07173',
#    'office_full': 'House',
#    'load_date': '2018-04-17T21:13:11+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2017-07-06',
#    'election_districts': ['07'],
#    'first_file_date': '2017-06-08',
#    'cycles': [2018],
#    'candidate_id': 'H8MO07173',
#    'name': 'EVANS, JIM',
#    'active_through': 2018,
#    'last_f2_date': '2017-07-06',
#    'district': '07',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 6,
#    'flags': 'H0MO06198',
#    'office_full': 'House',
#    'load_date': '2020-04-15T21:14:55+00:00',
#    'election_years': [2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2020-02-18',
#    'election_districts': ['06'],
#    'first_file_date': '2020-02-18',
#    'cycles': [2020],
#    'candidate_id': 'H0MO06198',
#    'name': 'FARRIS, RAMONA',
#    'active_through': 2020,
#    'last_f2_date': '2020-02-18',
#    'district': '06',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02132',
#    'office_full': 'House',
#    'load_date': '2018-01-09T21:09:43+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-02-25',
#    'election_districts': ['02'],
#    'first_file_date': '2017-02-25',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02132',
#    'name': 'FIELDS, VERNON JAMES',
#    'active_through': 2018,
#    'last_f2_date': '2017-02-25',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'O',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Open seat',
#    'district_number': 2,
#    'flags': 'H8KS02140',
#    'office_full': 'House',
#    'load_date': '2018-01-09T21:09:43+00:00',
#    'election_years': [2018],
#    'candidate_status': 'C',
#    'state': 'KS',
#    'last_file_date': '2017-05-17',
#    'election_districts': ['02'],
#    'first_file_date': '2017-04-01',
#    'cycles': [2018],
#    'candidate_id': 'H8KS02140',
#    'name': 'FITZGERALD, STEPHEN EDWARD',
#    'active_through': 2018,
#    'last_f2_date': '2017-05-17',
#    'district': '02',
#    'party': 'REP',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'REPUBLICAN PARTY'},
#   {'candidate_inactive': False,
#    'incumbent_challenge': 'C',
#    'federal_funds_flag': False,
#    'has_raised_funds': True,
#    'incumbent_challenge_full': 'Challenger',
#    'district_number': 3,
#    'flags': 'H8MO03198',
#    'office_full': 'House',
#    'load_date': '2019-08-05T21:05:21+00:00',
#    'election_years': [2018, 2020],
#    'candidate_status': 'C',
#    'state': 'MO',
#    'last_file_date': '2019-02-12',
#    'election_districts': ['03', '03'],
#    'first_file_date': '2018-02-14',
#    'cycles': [2018, 2020],
#    'candidate_id': 'H8MO03198',
#    'name': 'GEPPERT, KATY',
#    'active_through': 2020,
#    'last_f2_date': '2019-02-12',
#    'district': '03',
#    'party': 'DEM',
#    'office': 'H',
#    'inactive_election_years': None,
#    'party_full': 'DEMOCRATIC PARTY'}],
#  'pagination': {'page': 1, 'count': 50, 'pages': 3, 'per_page': 20}}

# %%
https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false
# Out:
#   File "<ipython-input-9-c541c7b7ccdc>", line 1
#     https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=url=f"https://api.open.fec.gov/v1/candidates/?api_key={api_key}"&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false
#           ^
# SyntaxError: invalid syntax

# %%
newurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key={api_key}&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false"

# %%
newurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/by_state/by_candidate/?sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&sort_hide_null=false&election_full=false&candidate_id=H8KS03155&candidate_id=H0KS02188&candidate_id=%20H8KS04112&candidate_id=H0KS01123&candidate_id=S0KS00315&candidate_id=S0KS00091&candidate_id=S8MO00160&candidate_id=S0MO00183&candidate_id=H8M001143&candidate_id=H2M002102&candidate_id=H8M009153&candidate_id=H0M004086&candidate_id=H4M005234&candidate_id=H0M006073&candidate_id=H0M007113&candidate_id=H4M008162&cycle=2014&cycle=2016&cycle=2018&cycle=2020&per_page=20&page=1&sort_nulls_last=false'

# %%
money=requests.get(newurl)

# %%
money.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'pages': 32, 'page': 1, 'per_page': 20, 'count': 627},
#  'results': [{'state': 'KS',
#    'cycle': 2014,
#    'state_full': 'Kansas',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 415.71},
#   {'state': 'KS',
#    'cycle': 2016,
#    'state_full': 'Kansas',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 75.0},
#   {'state': 'AR',
#    'cycle': 2020,
#    'state_full': 'Arkansas',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 2800.0},
#   {'state': 'AZ',
#    'cycle': 2020,
#    'state_full': 'Arizona',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 11200.0},
#   {'state': 'CA',
#    'cycle': 2020,
#    'state_full': 'California',
#    'count': 16,
#    'candidate_id': 'H0KS01123',
#    'total': 13770.2},
#   {'state': 'CO',
#    'cycle': 2020,
#    'state_full': 'Colorado',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 750.0},
#   {'state': 'DC',
#    'cycle': 2020,
#    'state_full': 'District Of Columbia',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 1750.0},
#   {'state': 'FL',
#    'cycle': 2020,
#    'state_full': 'Florida',
#    'count': 2,
#    'candidate_id': 'H0KS01123',
#    'total': 3050.0},
#   {'state': 'GA',
#    'cycle': 2020,
#    'state_full': 'Georgia',
#    'count': 2,
#    'candidate_id': 'H0KS01123',
#    'total': 475.0},
#   {'state': 'IL',
#    'cycle': 2020,
#    'state_full': 'Illinois',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 251.0},
#   {'state': 'KS',
#    'cycle': 2020,
#    'state_full': 'Kansas',
#    'count': 750,
#    'candidate_id': 'H0KS01123',
#    'total': 904158.16},
#   {'state': 'MD',
#    'cycle': 2020,
#    'state_full': 'Maryland',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 2100.0},
#   {'state': 'MI',
#    'cycle': 2020,
#    'state_full': 'Michigan',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 500.0},
#   {'state': 'MN',
#    'cycle': 2020,
#    'state_full': 'Minnesota',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 1000.0},
#   {'state': 'MO',
#    'cycle': 2020,
#    'state_full': 'Missouri',
#    'count': 47,
#    'candidate_id': 'H0KS01123',
#    'total': 49200.0},
#   {'state': 'ND',
#    'cycle': 2020,
#    'state_full': 'North Dakota',
#    'count': 4,
#    'candidate_id': 'H0KS01123',
#    'total': 5600.0},
#   {'state': 'NE',
#    'cycle': 2020,
#    'state_full': 'Nebraska',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 2800.0},
#   {'state': 'OK',
#    'cycle': 2020,
#    'state_full': 'Oklahoma',
#    'count': 3,
#    'candidate_id': 'H0KS01123',
#    'total': 1500.0},
#   {'state': 'OR',
#    'cycle': 2020,
#    'state_full': 'Oregon',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 250.0},
#   {'state': 'TN',
#    'cycle': 2020,
#    'state_full': 'Tennessee',
#    'count': 1,
#    'candidate_id': 'H0KS01123',
#    'total': 250.0}]}

# %%
ksurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per_page=20&sort_hide_null=false&sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&committee_id=C00109017"

# %%
ksurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per_page=20&sort_hide_null=false&sort_null_only=false&api_key=cKUzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&committee_id=C00109017'

# %%
ksmoney=requests.get(ksurl)

# %%
ksmoney.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'last_indexes': {'last_index': '4121620051062579651',
#    'sort_null_only': True},
#   'pages': 9565,
#   'per_page': 20,
#   'count': 191298},
#  'results': [{'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '20002 HORIZON BLUFF',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZURHEIDE',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC OPERATIONS INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'THOMAS E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18546839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782583151',
#    'contributor_name': 'ZURHEIDE, THOMAS E',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP-MARKET DEVELOPMENT',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579670',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '190 BRONSON DRIVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZUPKUS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MIDDLEBURY',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'KEVIN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10296839',
#    'contributor_state': 'CT',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '067622319',
#    'contributor_name': 'ZUPKUS, KEVIN A',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP LABOR RELATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579669',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '14 LOCUST DR',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZOLLMANN',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLORISSANT',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'M MICHELLE',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18442839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '630318221',
#    'contributor_name': 'ZOLLMANN, M MICHELLE',
#    'image_number': '25971603261',
#    'contributor_occupation': 'DIRECTOR',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579668',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6N071 MEREDITH RD.',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZANG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MAPLE PARK',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DONNA',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR339683839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601518624',
#    'contributor_name': 'ZANG, DONNA',
#    'image_number': '25971603261',
#    'contributor_occupation': 'HR EMPLOYEE RELATIONS MANAGER II',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579667',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2802CHRISTOPHER BLUFFS',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZALOUDEK',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'OAKVILLE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL YELLOW PAGES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'JOHN M',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18173839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '63129',
#    'contributor_name': 'ZALOUDEK, JOHN M',
#    'image_number': '25971603261',
#    'contributor_occupation': 'MANAGING DIRECTOR ADVERTISING SERVICES',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579666',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6716 CHANNEL RD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZAKRZEWSKI',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WATERFORD',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'AMERITECH SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'COLLEEN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR13498839',
#    'contributor_state': 'WI',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '531852529',
#    'contributor_name': 'ZAKRZEWSKI, COLLEEN A',
#    'image_number': '25971603260',
#    'contributor_occupation': 'MANAGER-QUALITY/M&P/PROCESS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579665',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1248 HEATHER HILL',
#    'contribution_receipt_amount': 35.16,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': 'CRESCENT',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLOSSMOOR',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TROY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 384.36,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR868839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '604221454',
#    'contributor_name': 'YOUNG, TROY L',
#    'image_number': '25971603260',
#    'contributor_occupation': 'LEAD CONTRACTING/SOURCING SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($17.58 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579664',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '11823 ELMSCOURT',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC MANAGEMENT SERVICES L.P.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DAVID ALAN',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR15121839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782302768',
#    'contributor_name': 'YOUNG, DAVID ALAN',
#    'image_number': '25971603260',
#    'contributor_occupation': 'HEAD OF FLIGHT OPERATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579663',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1184 N LNDA VSTA ST',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOSS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ORANGE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'PACIFIC BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MARIA E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR20411839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '928691315',
#    'contributor_name': 'YOSS, MARIA E',
#    'image_number': '25971603259',
#    'contributor_occupation': 'STAFF SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579662',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '5598 KING ROAD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YEAGER',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'LOOMIS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MICHAEL A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR19695839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '956509085',
#    'contributor_name': 'YEAGER, MICHAEL A',
#    'image_number': '25971603259',
#    'contributor_occupation': 'SENIOR DATA ANALYST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579661',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2567 39TH AVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YAM',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'SUNG-LING',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10823839',
# ...
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579654',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1784 CUMBERLAND GREEN',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOOD',
#    'contributor_street_2': 'UNIT #348',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ST CHARLES',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DEBORAH K',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR21687839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601744644',
#    'contributor_name': 'WOOD, DEBORAH K',
#    'image_number': '25971603256',
#    'contributor_occupation': 'BUSINESS MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579653',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '140 LONGFELLOW DR,',
#    'contribution_receipt_amount': 18.8,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WONG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WHEATON',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'EMILY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 205.45,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR3248839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601877410',
#    'contributor_name': 'WONG, EMILY L',
#    'image_number': '25971603256',
#    'contributor_occupation': 'PROJECT MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($9.40 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579652',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '13618 PRISTINE LAKE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOLFF',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'CYPRESS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TIMOTHY J',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18216839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '774296008',
#    'contributor_name': 'WOLFF, TIMOTHY J',
#    'image_number': '25971603256',
#    'contributor_occupation': 'TOP CONSTRUCTION & ENGINEERING OF A RE',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579651',
#    'candidate_office_state': None}]}

# %%
newnewurl=f"https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per[…]UzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&contributor_zip=66604"

# %%
newnewurl
# Out:
# 'https://api.open.fec.gov/v1/schedules/schedule_a/?sort=-contribution_receipt_date&per[…]UzXnqasaxmD3l9mDOOD5wqRfZ0rnYuZJzxKnhx&contributor_zip=66604'

# %%
newnew=requests.get(ksurl)

# %%
newnew.json()
# Out:
# {'api_version': '1.0',
#  'pagination': {'last_indexes': {'last_index': '4121620051062579651',
#    'sort_null_only': True},
#   'pages': 9565,
#   'per_page': 20,
#   'count': 191298},
#  'results': [{'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '20002 HORIZON BLUFF',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZURHEIDE',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC OPERATIONS INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'THOMAS E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18546839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782583151',
#    'contributor_name': 'ZURHEIDE, THOMAS E',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP-MARKET DEVELOPMENT',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579670',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '190 BRONSON DRIVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZUPKUS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MIDDLEBURY',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'KEVIN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10296839',
#    'contributor_state': 'CT',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '067622319',
#    'contributor_name': 'ZUPKUS, KEVIN A',
#    'image_number': '25971603262',
#    'contributor_occupation': 'AVP LABOR RELATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603262',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579669',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '14 LOCUST DR',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZOLLMANN',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLORISSANT',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'M MICHELLE',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18442839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '630318221',
#    'contributor_name': 'ZOLLMANN, M MICHELLE',
#    'image_number': '25971603261',
#    'contributor_occupation': 'DIRECTOR',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579668',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6N071 MEREDITH RD.',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZANG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'MAPLE PARK',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DONNA',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR339683839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601518624',
#    'contributor_name': 'ZANG, DONNA',
#    'image_number': '25971603261',
#    'contributor_occupation': 'HR EMPLOYEE RELATIONS MANAGER II',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579667',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2802CHRISTOPHER BLUFFS',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZALOUDEK',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'OAKVILLE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL YELLOW PAGES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'JOHN M',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18173839',
#    'contributor_state': 'MO',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '63129',
#    'contributor_name': 'ZALOUDEK, JOHN M',
#    'image_number': '25971603261',
#    'contributor_occupation': 'MANAGING DIRECTOR ADVERTISING SERVICES',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603261',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579666',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '6716 CHANNEL RD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'ZAKRZEWSKI',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WATERFORD',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'AMERITECH SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'COLLEEN A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR13498839',
#    'contributor_state': 'WI',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '531852529',
#    'contributor_name': 'ZAKRZEWSKI, COLLEEN A',
#    'image_number': '25971603260',
#    'contributor_occupation': 'MANAGER-QUALITY/M&P/PROCESS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579665',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1248 HEATHER HILL',
#    'contribution_receipt_amount': 35.16,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': 'CRESCENT',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'FLOSSMOOR',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TROY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 384.36,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR868839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '604221454',
#    'contributor_name': 'YOUNG, TROY L',
#    'image_number': '25971603260',
#    'contributor_occupation': 'LEAD CONTRACTING/SOURCING SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($17.58 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579664',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '11823 ELMSCOURT',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOUNG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN ANTONIO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC MANAGEMENT SERVICES L.P.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DAVID ALAN',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR15121839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '782302768',
#    'contributor_name': 'YOUNG, DAVID ALAN',
#    'image_number': '25971603260',
#    'contributor_occupation': 'HEAD OF FLIGHT OPERATIONS',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603260',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579663',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1184 N LNDA VSTA ST',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YOSS',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ORANGE',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'PACIFIC BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MARIA E',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR20411839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '928691315',
#    'contributor_name': 'YOSS, MARIA E',
#    'image_number': '25971603259',
#    'contributor_occupation': 'STAFF SPECIALIST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579662',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '5598 KING ROAD',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YEAGER',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'LOOMIS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'MICHAEL A',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR19695839',
#    'contributor_state': 'CA',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '956509085',
#    'contributor_name': 'YEAGER, MICHAEL A',
#    'image_number': '25971603259',
#    'contributor_occupation': 'SENIOR DATA ANALYST',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603259',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579661',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '2567 39TH AVE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'YAM',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'SAN FRANCISCO',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'SUNG-LING',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR10823839',
# ...
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579654',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '1784 CUMBERLAND GREEN',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOOD',
#    'contributor_street_2': 'UNIT #348',
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'ST CHARLES',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'DEBORAH K',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR21687839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601744644',
#    'contributor_name': 'WOOD, DEBORAH K',
#    'image_number': '25971603256',
#    'contributor_occupation': 'BUSINESS MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579653',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '140 LONGFELLOW DR,',
#    'contribution_receipt_amount': 18.8,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WONG',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'WHEATON',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SBC SERVICES INC.',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'EMILY L',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 205.45,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR3248839',
#    'contributor_state': 'IL',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '601877410',
#    'contributor_name': 'WONG, EMILY L',
#    'image_number': '25971603256',
#    'contributor_occupation': 'PROJECT MANAGER',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($9.40 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579652',
#    'candidate_office_state': None},
#   {'memoed_subtotal': False,
#    'entity_type': 'IND',
#    'back_reference_schedule_name': None,
#    'contributor': None,
#    'original_sub_id': None,
#    'contributor_suffix': None,
#    'report_type': 'M12',
#    'contributor_street_1': '13618 PRISTINE LAKE',
#    'contribution_receipt_amount': 20.0,
#    'receipt_type_full': None,
#    'amendment_indicator': 'A',
#    'amendment_indicator_desc': 'ADD',
#    'file_number': 193676,
#    'conduit_committee_id': None,
#    'conduit_committee_street2': None,
#    'schedule_type': 'SA',
#    'candidate_office': None,
#    'contributor_last_name': 'WOLFF',
#    'contributor_street_2': None,
#    'contribution_receipt_date': None,
#    'contributor_id': None,
#    'report_year': 2005,
#    'contributor_city': 'CYPRESS',
#    'recipient_committee_org_type': 'C',
#    'conduit_committee_zip': None,
#    'national_committee_nonfederal_account': None,
#    'contributor_employer': 'SOUTHWESTERN BELL TELEPHONE COMPANY',
#    'link_id': 4121620051062565342,
#    'contributor_first_name': 'TIMOTHY J',
#    'candidate_middle_name': None,
#    'committee_name': None,
#    'candidate_office_state_full': None,
#    'load_date': '2017-06-17T19:13:41.905361+00:00',
#    'candidate_prefix': None,
#    'election_type': None,
#    'election_type_full': None,
#    'contributor_aggregate_ytd': 220.0,
#    'filing_form': 'F3X',
#    'transaction_id': 'PR18216839',
#    'contributor_state': 'TX',
#    'increased_limit': None,
#    'donor_committee_name': None,
#    'contributor_zip': '774296008',
#    'contributor_name': 'WOLFF, TIMOTHY J',
#    'image_number': '25971603256',
#    'contributor_occupation': 'TOP CONSTRUCTION & ENGINEERING OF A RE',
#    'conduit_committee_state': None,
#    'candidate_name': None,
#    'fec_election_year': None,
#    'fec_election_type_desc': None,
#    'memo_text': 'P/R DEDUCTION ($10.00 SEMI-MONTHLY)',
#    'contributor_middle_name': None,
#    'entity_type_desc': 'INDIVIDUAL',
#    'conduit_committee_city': None,
#    'pdf_url': 'http://docquery.fec.gov/cgi-bin/fecimg/?25971603256',
#    'recipient_committee_type': 'Q',
#    'committee': {'filing_frequency': 'M',
#     'committee_type': 'Q',
#     'affiliated_committee_name': 'AT&T INC.',
#     'former_candidate_id': None,
#     'designation': 'U',
#     'convert_to_pac_flag': False,
#     'cycles_has_financial': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'sponsor_candidate_ids': None,
#     'former_candidate_name': None,
#     'committee_type_full': 'PAC - Qualified',
#     'state': 'TX',
#     'party': None,
#     'party_full': None,
#     'street_1': '175 E. Houston Street',
#     'designation_full': 'Unauthorized',
#     'city': 'San Antonio',
#     'last_cycle_has_activity': 2022,
#     'candidate_ids': [],
#     'former_candidate_election_year': None,
#     'committee_id': 'C00109017',
#     'treasurer_name': 'Klug, Jonathan P.',
#     'name': 'AT&T INC. FEDERAL POLITICAL ACTION COMMITTEE (AT&T FEDERAL PAC)',
#     'last_cycle_has_financial': 2022,
#     'state_full': 'Texas',
#     'is_active': True,
#     'cycles': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'zip': '78205',
#     'organization_type_full': 'Corporation',
#     'cycles_has_activity': [1980,
#      1982,
#      1984,
#      1986,
#      1988,
#      1990,
#      1992,
#      1994,
#      1996,
#      1998,
#      2000,
#      2002,
#      2004,
#      2006,
#      2008,
#      2010,
#      2012,
#      2014,
#      2016,
#      2018,
#      2020,
#      2022],
#     'organization_type': 'C',
#     'former_committee_name': None,
#     'street_2': 'Room 7-A-50',
#     'cycle': 2006},
#    'contributor_prefix': None,
#    'committee_id': 'C00109017',
#    'conduit_committee_street1': None,
#    'unused_contbr_id': None,
#    'recipient_committee_designation': 'U',
#    'candidate_office_full': None,
#    'memo_code_full': None,
#    'schedule_type_full': 'ITEMIZED RECEIPTS',
#    'receipt_type': None,
#    'back_reference_transaction_id': None,
#    'receipt_type_desc': None,
#    'two_year_transaction_period': 2006,
#    'candidate_first_name': None,
#    'line_number': '11AI',
#    'line_number_label': 'Contributions From Individuals/Persons Other Than Political Committees',
#    'candidate_last_name': None,
#    'candidate_office_district': None,
#    'conduit_committee_name': None,
#    'is_individual': True,
#    'candidate_id': None,
#    'candidate_suffix': None,
#    'memo_code': None,
#    'sub_id': '4121620051062579651',
#    'candidate_office_state': None}]}

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
db = client.FollowTheMoney
members_collection = db.members
